# %% [markdown]
# <center>
# <h1>基于pytorch + LSTM 的古诗生成</h1>
# </center>

# %% [markdown]
# ### 课程介绍:
# 本课程使用pytorch框架, 完成NLP任务:古诗生成,使用的模型为 LSTM, 并训练了词向量, 支持随机古诗和藏头诗生成, 并且生成的古诗具有多变性。在课堂中会从0完成代码的编写，并分为多个文件，以便对比。

# %% [markdown]
# <br>

# %% [markdown]
# ### 导包:

# %%
import os
import numpy as np
import pickle
import torch
import torch.nn as nn
from gensim.models.word2vec import Word2Vec
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# <br>

# %% [markdown]
# ### 生成切分文件:

# %%
def split_text(file="poetry_7.txt", train_num=6000):
    all_data = open(file, "r", encoding="utf-8").read()
    with open("split_7.txt", "w", encoding="utf-8") as f:
        split_data = " ".join(all_data)
        f.write(split_data)
    return split_data[:train_num * 64]

# %% [markdown]
# <br>

# %% [markdown]
# ### 训练词向量:

# %%
def train_vec(split_file="split_7.txt", org_file="poetry_7.txt", train_num=6000):
    param_file = "word_vec.pkl"
    org_data = open(org_file, "r", encoding="utf-8").read().split("\n")[:train_num]
    if os.path.exists(split_file):
        all_data_split = open(split_file, "r", encoding="utf-8").read().split("\n")[:train_num]
    else:
        all_data_split = split_text().split("\n")[:train_num]

    if os.path.exists(param_file):
        return org_data, pickle.load(open(param_file, "rb"))

    models = Word2Vec(all_data_split, vector_size=128, workers=7, min_count=1)
    pickle.dump([models.syn1neg, models.wv.key_to_index, models.wv.index_to_key], open(param_file, "wb"))
    return org_data, (models.syn1neg, models.wv.key_to_index, models.wv.index_to_key)

# %% [markdown]
# <br>

# %% [markdown]
# ### 构建数据集:

# %%
class Poetry_Dataset(Dataset):
    def __init__(self, w1, word_2_index, all_data):
        self.w1 = w1
        self.word_2_index = word_2_index
        self.all_data = all_data

    def __getitem__(self, index):
        a_poetry = self.all_data[index]

        a_poetry_index = [self.word_2_index[i] for i in a_poetry]
        xs = a_poetry_index[:-1]
        ys = a_poetry_index[1:]
        xs_embedding = self.w1[xs]

        return xs_embedding, np.array(ys).astype(np.int64)

    def __len__(self):
        return len(self.all_data)

# %% [markdown]
# <br>

# %% [markdown]
# ### 模型构建:

# %%
class Poetry_Model_lstm(nn.Module):
    def __init__(self, hidden_num, word_size, embedding_num):
        super().__init__()

        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.hidden_num = hidden_num

        self.lstm = nn.LSTM(input_size=embedding_num, hidden_size=hidden_num, batch_first=True, num_layers=2,
                            bidirectional=False)
        self.dropout = nn.Dropout(0.3)
        self.flatten = nn.Flatten(0, 1)
        self.linear = nn.Linear(hidden_num, word_size)
        self.cross_entropy = nn.CrossEntropyLoss()

    def forward(self, xs_embedding, h_0=None, c_0=None):
        if h_0 == None or c_0 == None:
            h_0 = torch.tensor(np.zeros((2, xs_embedding.shape[0], self.hidden_num), dtype=np.float32))
            c_0 = torch.tensor(np.zeros((2, xs_embedding.shape[0], self.hidden_num), dtype=np.float32))
        h_0 = h_0.to(self.device)
        c_0 = c_0.to(self.device)
        xs_embedding = xs_embedding.to(self.device)
        hidden, (h_0, c_0) = self.lstm(xs_embedding, (h_0, c_0))
        hidden_drop = self.dropout(hidden)
        hidden_flatten = self.flatten(hidden_drop)
        pre = self.linear(hidden_flatten)

        return pre, (h_0, c_0)

# %% [markdown]
# <br>

# %% [markdown]
# ### 自动生成古诗:

# %%
def generate_poetry_auto():
    result = ""
    word_index = np.random.randint(0, word_size, 1)[0]

    result += index_2_word[word_index]
    h_0 = torch.tensor(np.zeros((2, 1, hidden_num), dtype=np.float32))
    c_0 = torch.tensor(np.zeros((2, 1, hidden_num), dtype=np.float32))

    for i in range(31):
        word_embedding = torch.tensor(w1[word_index][None][None])
        pre, (h_0, c_0) = model(word_embedding, h_0, c_0)
        word_index = int(torch.argmax(pre))
        result += index_2_word[word_index]

    return result

# %% [markdown]
# <br>

# %% [markdown]
# ### 藏头诗生成:

# %%
def generate_poetry_acrostic():
    input_text = input("请输入四个汉字：")[:4]
    result = ""
    punctuation_list = ["，", "。", "，", "。"]
    for i in range(4):
        result += input_text[i]
        h_0 = torch.tensor(np.zeros((2, 1, hidden_num), dtype=np.float32))
        c_0 = torch.tensor(np.zeros((2, 1, hidden_num), dtype=np.float32))
        word = input_text[i]
        for j in range(6):
            word_index = word_2_index[word]
            word_embedding = torch.tensor(w1[word_index][None][None])
            pre , (h_0,c_0) = model(word_embedding,h_0,c_0)
            word = word_2_index[int(torch.argmax(pre))]
            result += word

    return result

# %% [markdown]
# <br>

# %% [markdown]
# ### 主函数: 定义参数, 模型, 优化器, 模型训练

# %%
if __name__ == "__main__":

    all_data, (w1, word_2_index, index_2_word) = train_vec(train_num=300)

    batch_size = 32
    epochs = 1000
    lr = 0.01
    hidden_num = 128
    word_size, embedding_num = w1.shape

    dataset = Poetry_Dataset(w1, word_2_index, all_data)
    dataloader = DataLoader(dataset, batch_size)

    model = Poetry_Model_lstm(hidden_num, word_size, embedding_num)
    model = model.to(model.device)

    optimizer = torch.optim.AdamW(model.parameters(), lr=lr)

    for e in range(epochs):
        for batch_index, (batch_x_embedding, batch_y_index) in enumerate(dataloader):
            model.train()
            batch_x_embedding = batch_x_embedding.to(model.device)
            batch_y_index = batch_y_index.to(model.device)

            pre, _ = model(batch_x_embedding)
            loss = model.cross_entropy(pre, batch_y_index.reshape(-1))

            loss.backward()  # 梯度反传 , 梯度累加, 但梯度并不更新, 梯度是由优化器更新的
            optimizer.step()  # 使用优化器更新梯度
            optimizer.zero_grad()  # 梯度清零

            if batch_index % 100 == 0:
                # model.eval()
                print(f"loss:{loss:.3f}")
                print(generate_poetry_auto())
# Out:
# loss:8.173
# 趁人息息息，西，。标，问。。。。。，息，，。，，，。。，。。。，
# loss:7.054
# 抱，，。，，，，。。，，，，，。，，。，。，。。。，，，，。，，
# loss:6.855
# 凛，。。。，。，，，。，。，。，。，。。。。。，。。。。。。，。
# loss:6.725
# 士。。。，。。，，，，，，。，。。。。。。。，，，。。。，，，，
# loss:6.724
# 骢山，，，。。，。。。。，，，，。，。。，，，。。，。。。。，。
# loss:6.691
# 唱山山，。。。，。。。，。。。。。。。，。，。，，。。。。。。。
# loss:6.636
# 罕门三山，，，。，。。，，，，，，。。，。。，。。。。。。。。，
# loss:6.621
# 头得高无海。，，，，。。，。，，。。。，。。，，。，，。。。，。
# loss:6.575
# 断得路无，，，，，，。，，。。。。，。。。，。。。。。，，，。。
# loss:6.565
# 格门三光海，，，。，，，。。。，。。。，。。。。。。。。。。，。
# loss:6.534
# 甡门高光，，，，，。，，。，。。，，，。。。，。。。。。，。。。
# loss:6.507
# 勋台风山，，，，，，，，，，。。，。。，，，，。。。，，。。。。
# loss:6.485
# 予门喧路，，，，，，。。。。。。。。。。。，。。。。。。。。。。
# loss:6.452
# 纨色风光生，，，，，，。，，。。。。。。。。。。。。。。，。。。
# loss:6.428
# 岸门风光千生，，，，，，。。。。。。。。。。。，。。。。。。。。
# loss:6.412
# 障有不车斗生，，，。，。。。。。。。。。。。。。。。。。。。。。
# loss:6.379
# 设得风光度，，，，，，，。。。。。。。。。。。，。。。。。。。。
# loss:6.351
# 毛人高光度天，，，，，，。。。。。。。。。。。。，。。。。。。。
# loss:6.333
# 怨人风光不海，，，，，不海，，，。海。。。。一。。。。。海。。。
# loss:6.293
# 寒色下车海生，，。一一一，，一一。。一。海，。。。海海，。。。海
# loss:6.259
# 美得若无三林，，。一海一，一。海，。。不海天，，。海。一海。。一
# loss:6.251
# 吉本若车三天，，，一一一，。一。不一。。来。。山天。。一。一。一
# loss:6.186
# 汀帆三无三天，，一山山山，一山花，一。。山山。。山。。。山山山。
# loss:6.104
# 羁帆三光香天，，，一山山。。。一一。。。一。一。。。不。。，一，
# loss:5.988
# 恶门极光海天，，一山一山不。。山人人不。。。海。不。不。一。一。
# loss:5.940
# 官是烟结海天，，一山一山。，一来不。。山一。一。一。一。一，一。
# loss:5.837
# 诙得风气三天，，一山不山一。。，一山一人一。一，一人一天一。。山
# loss:5.800
# 诛有不路倏林，，一山一天一。。来一风一。。，不山一人一。。里一人
# loss:5.733
# 赭色风路生天，，一山不山不。。今一人一天。。雄山一风一。一来不人
# loss:5.684
# 高色喧树斗天，，，光如光一。一。一风一。一，一。一人一。一，一山
# loss:5.620
# 命门小光三天空，一山一气水天。。山来如人一。。有风风一水。。来年
# loss:5.582
# 编帆三路三峰天，一山台光不水。。一山无人一。一。一年一。花。一。
# loss:5.521
# 戎有喧香斗千菲，一山如此一。人。一山一天有。一里一年一时。。一是
# loss:5.509
# 悦迷古光三千，，一载一子一。香。一年一人城。一来一人不。一。一来
# loss:5.474
# 寞得梅路六千，，一来一溪一色。。山来花一无。，一里一人不。夜，一
# loss:5.457
# 唶闻山光来生天，一山一篱旧。花。一风一。一。一。一。一云夜。一。
# loss:5.426
# 伫迷吞光斗海，，一然如山水。一来一时重清。。但里一人闲。海。一来
# loss:5.391
# 宕身高路三天天，一山新山作节心。一山一山一时。，一来一山不人。。
# loss:5.372
# 麓来三柳三天，，秋锁风天一公。。里风山一时。。海里一有有。海。一
# loss:5.338
# 状台风光三天天，老来估溪一无香。一来当人一无花。一山一望一仔。，
# loss:5.330
# 牖有风路生海，，一贲如气一天。。他来风有红。。山风声不无。，一风
# loss:5.286
# 急仙风光香难，，一偏台阁更。香。一影一此香。一来一人不无来。一山
# loss:5.354
# 该迷互树斗水天，砌然一入旧山端。不来不山不无青，一是一风一无。。
# loss:5.298
# 踏开喧光香天城，一圃一阁一楼公。一里枯年无无。。不天一人一无。，
# loss:5.283
# 巨门高光生一天，一来一溪一水心。海是一年一海香。一山一斜一无天。
# loss:5.271
# 盖兆若光生三开，一圃一溪旧牛场。一来一风一时有，一山一声一时来，
# loss:5.251
# 摋来古树似天天，，灵编贵一天城。一是一影不人肩。一来一山一田青，
# loss:5.218
# 贝开风路开重天，蟹门编里旧。微。一里一雨天时青，一是一风一海。，
# loss:5.203
# 臂开烟光六峰空，一山一光一山端。一里枯影一公仙，一山一风耆清来，
# loss:5.163
# 丛萧三光三自过，瘴灵清花一天心。一来风年一，更，一风不公会，一来
# loss:5.137
# 缳迷梅软斗自，，隐台篱入不春天。一到一翁不生仙。一到枯头争黄林，
# loss:5.136
# 埤迷西软斗峰菲，文望台味一天天。吟是一德不色胧。一来一年一时胧，
# loss:5.115
# 量榜风路三海宽，一圃呵阁更。心。一来一人新。一来一风来。有，一山
# loss:5.055
# 蒲本由传一若宣，一然一溪烦天端。一是一人无无会，一来一处一云微。
# loss:5.131
# 攀海宜空度自天，一山一里一浮场。一山风年耆尧青，争山一年无。绿。
# loss:5.054
# 胆来梅柳斗绩菲，瘴山编舞一天。。更教一时重等扉，一发一人一不花。
# loss:4.976
# 鼋迷古树斗绩菲，瘴将无山一天。。清风成有数黑，，海已涛不多治，一
# loss:4.921
# 鑱抡更柳入峰履，蟹讶一护一天公。一海一年一气线，万山一年一无老。
# loss:4.842
# 巨门风路性生，，千偏新叶一染人。更上一房一首处，未里一用一兴花。
# loss:4.825
# 造茫花光海千宽，一歌罗子旧天篇。一天一有初人肩，一里一蜞一老肩。
# loss:4.771
# 乱门喧光性天天，一山富贵早回端。海知一日初云句，一里遥人天知阴。
# loss:4.743
# 承耳鸟路海生宽，一世黄咏蓬超鸣。一是一日两尧里，万山一望寸梦青。
# loss:4.714
# 琐人风命远上空，一山富贵早超妍。赤得斗回天老句，一山一。一来细。
# loss:4.728
# 濠萧棕光六熳天，三，清光如溪回。吟是但梅一敷治，一山遥年一时飞。
# loss:4.687
# 矣璃风光庆自筵，偶章成花旧笔妍。十上一层重济处，黄得弼香一仔违。
# loss:4.634
# 嫌今无路六重豪，文鱼台光映笔妍。一甲盛德不敷治，万竿遥年两尧。。
# loss:4.645
# 杖门筛路六擎浓，一溟如溪到天滨。不教一灯不醇治，一遣遥园一禅仙。
# loss:4.670
# 太人繁叟性天宽，文见载校乌笔场。一是一年初圣世，一长遥年一大铨。
# loss:4.550
# 苏门由阮性若叶，金门富掌入不莲。不阁一年有海里，争奏烟影初野径。
# loss:4.527
# 绛台若禽新千天，一将清堆一诗萍。。萼揽星知敷醪，回竿佳丑客不。。
# loss:4.493
# 握色九长千峰它，况将清阁吐兰场。十是如日重圣臂，一山一秤一禅铨。
# loss:4.441
# 衿郎三扬按料宽，一歌身贵早战场。白露不今重大阔，一长犹德一沧红。
# loss:4.409
# 杵有九目庆有垧，甘灵清护烦诗公。菜知一肃随柏化，一山一望一园颠。
# loss:4.413
# 菲门觉阮三有，，一衔如惯霸然羊。一知一年有筋重，一到西忆不纤颠。
# loss:4.354
# 吴帆若十接画空，忽门初护吐母昂。吟教一风初大句，一落一时一仔有。
# loss:4.358
# 散络三空按廊场，甘龙富子蓬壶端。极阁突德来敷治，一及如山夜仔有。
# loss:4.406
# 贞人风彩侍氏先，一圃黄子旧摧端。遥封一舒不园醪，回浦一年一如世。
# loss:4.402
# 嫣载洗街昙天省，亲章编化更天寻。百家不今留圣狗，愿船诗情逢虫扉。
# loss:4.475
# 帙销教涤争蜜薇，踏下枫阁一用微。一是一年常醉世，腹遣遥山一等铨。
# loss:4.457
# 缃围古树只掌筵，祇锁清花一相忙。一教斗引谁敷治，争及一灂常藓铺。
# loss:4.286
# 丑秋高车暗罅卮，将落天里一染微。一米如日谁圣世，一遣遥叶一大肩。
# loss:4.257
# 擘烟九月总掌筵，古贲灰阁一节屏。遥来不年重圣泣，一竿一层洵瓶涝。
# loss:4.151
# 菜一负胥铺印题，一步清叶一染铨。自采不作添朦胧，海氛遥山一翠铨。
# loss:4.138
# 彰来梅柳祇芳硜，细歌天溪一翠吟。十发不道先野世，愿雄一影重峡涝。
# loss:4.110
# 资目极目庆岛筵，一圃灰匀蓬笔端。十阁当年潮何妇，丹颜应影尚留青。
# loss:4.054
# 殖势古树千呼客，祇凭呵味烦厄公。荡寞纵尔呕折治，愿雄衔羞几蚌桑。
# loss:4.001
# 饥蛇轻街禄峰远，匹章呵没水水长。王到揽辔本窟热，极耳一声细子青。
# loss:3.974
# 翰丛村墟奏琳瓜，，挹呵师烦天持。。缨握震能户渡，此来猿壳柁枕位。
# loss:3.924
# 鼛蟹题欺觚峰远，一锁赘老一愚赊。萸缨年影偕野鹤，一犁黄莽不春丸。
# loss:3.860
# 衮堂潮残碧淼阳，匹阶台舶佐领伺。笋。消蜍甚瑚櫜，止月一瓠重仔肩。
# loss:3.869
# 亮有九车政绩绦，精潮初篱气天同。昆知斗惭禾江考，黄来吹珓一舜廷。
# loss:3.862
# 飧节村钵千非它，祇盖清妨烦裁红。一家一音知济挑，一指春人一轮铨。
# loss:3.805
# 判开盘叟渡葸襦，砌门编烛亦壮屏。争目纵肉呕公死，一及我斋尚心觫。
# loss:3.898
# 摹义由姿菊其化，一原壁棱荖跻觞。菜囊盛随来敷治，栽臣我此乐涛堤。
# loss:3.824
# 玲帆极目杯孙鼛，庭山初壁灿入鸣。计采一今初醉狗，华及我兮不蛟颠。
# loss:3.757
# 滟与夏樯廿雕婢，鲤腊江慕一天州。换芟恶洲辛勤亮，屠戟普时重仔肩。
# loss:3.777
# 琅施图光力花沙，蛋圃一唱焚粉嚣。满儿饥俚痿时国，争涛壁垒童泛静，
# loss:3.731
# 鞍门极目来偶凶，振暖罗护舵山香。残阁明划清知夜，携是文业话纷筵。
# loss:3.718
# 牖门暖目醉孙妍，舵圃一溪尤辔哗。怪萼逸藤辛勤亮，尘月遥人慎解翅。
# loss:3.782
# 倾葛渔喙总卒襦，一世结涩苦入中。。知背沌楚英贾，一避頳莽共辟目。
# loss:3.918
# 跎重教钵到海贫，破锁没没悦天长。残知裹银殊江皋，未谷劝皆耸瞬颾。
# loss:3.918
# 貌来梅柳暗大旗，一然清溪汗漫赊。阄宇一今月额少，故天似恋刺大飞。
# loss:3.831
# 疲销不卷意一宽，散漩眷历不帆羊。一对簿舒陶钧绿，笋鞭不年一等铨。
# loss:3.640
# 轩耳由路性生溶，功名倒口毗水篇。澄缨握树常双翦，耆漫斑徧徒伊咎。
# loss:3.574
# 珠本标击控斜萤，一山一令美与碑。此势渐随秋敷治，愿夫蹴父远象桓。
# loss:3.515
# 宅榜三蕤旧双，，岛穰利荣羡子霆。輶露无道烦酋长，不省供障悟青花。
# loss:3.421
# 缩中但吞到峰臼，南然江溪叱爪鞭。散杨应随随凤幻，故湃涛人野息猜。
# loss:3.490
# 量治群推谪氏先，蟹嵌针遍入咏城。尔思纸耳蛤蚌重，万梦遥年达论墙。
# loss:3.430
# 契人小插引卒瓅，脂疏身校蓬回山。佛锐明灯未染喜，送鞭从人扫妾窝。
# loss:3.388
# 帖微神邑祇粗广，踏歌仙国最属菜。芒醒饥头奚首世，故唤惆卧不瞬仙。
# loss:3.421
# 太今花土都农化，蠹亚珠骚为诃民。澄仍纡回判英会，笋鞭青槎慰唐吟。
# loss:3.346
# 寿余周姿三螺遭，筠眼欢勒加鞍筹。盛音耆沸终翔翱，旗是沉业话沧旻。
# loss:3.320
# 乌榜觉路渡渊森，蟹世抵骑聊青频。荡十扬有菩提果，醉立舌愧不老仙。
# loss:3.295
# 石罗元瓦还宰练，更样先贾达虎嚣。白风骀是归额远，腹来雪啸挛腰吟。
# loss:3.307
# 誉门良蔗三自天，功名拍仆毗沧娇。澄谋衔献知折伏，不汁遥叶一王铃。
# loss:3.347
# 疴势灰涤苦苗开，涌山新岁一车。。命舆已荒左野，，梦培黄安不瓶仙。
# loss:3.358
# 判身破举划莽伏，筠翻清市纵荜端。荡艎揽辔知公志，愿飙弼家事渔虎。
# loss:3.403
# 璎得三圃都绸缪，老山厉燕学前妆。他石观有闲雕素，栽培我卧陶廉青。
# loss:3.304
# 歌仙高结营林见，砌下椰子还峥趋。小笑一头回幽涩，畅唤頳此傍渺米。
# loss:3.336
# 脸罗棕空八掌鼛，牙身编篱蓬嚣时。菜青不圃回首运，争培壁垒几沧桑。
# loss:3.324
# 塞马舂人渐画屏，秋艳子原外粉评。赤霆纡回判沙线，涸月应竹争禅扉。
# loss:3.285
# 局帆西雾营绩宣，甘娘罔市赋琉莲。澄清揽辔鲲抵手，式来无调归滔员。
# loss:3.254
# 刀台西森接绝岚，瘴章此畔授伤情。拂目晴兀销兰化，化院普影添朦胧。
# loss:3.177
# 约月盆目炎千枝，笥首磷靡渴名情。忘机骇肉兼番矿，旗出拍旭丽旌衣。
# loss:3.173
# 庆榜宠路香生履，振秋初初费遮场。异笑枯洋凭人热，要所骢迥映膏涂。
# loss:3.124
# 久幅群便破孙僮，蟹落潜西客于浆。不舟坐镇昙壶胡，一山底岸贡全饱。
# loss:3.188
# 芋来梅柳暗杨柳，雾看鲁鹤夕天祟。拂差竹震黄曛绿，黄胎相山动壶客。
# loss:3.189
# 派人无涘心名澄，门沙庄匀苦魔走。。星莫涨乐白壕，回氛先味脍酸魛。
# loss:3.420
# 衔泛把鱼蹄其手，赤屋欢咏软珊师。芒翁有荒同兵渡，栽及我珠不飕仙。
# loss:3.603
# 项清吐吞到清贫，大仔芒前草荻芦。贪懒纵露山凝雾，故山积交挛腰脐。
# loss:3.331
# 乍钧群香又三申，陆班呵阖蓬虎鸣。孝经课诵逃忠静，涸湃一望红。亭魄
# loss:3.105
# 视身娇脆似水元，士转泻此殄南茅。绣懒千年留提果，一供昏舒不飕仙。
# loss:3.122
# 觫秋环车暗变披，秋歌还看受画门。他板乞肉臻杯到，守柯洪涛冠魄中。
# loss:2.997
# 牙却飞蔗性自阳，振笼呵光映笔官。元经耆肉抱公济，此来图验柁尧位。
# loss:3.035
# 坚得淡锦迥拍伦，偶稻编篱旧短官。此腾盛喜横染绿，笋心青兴闹洞饱。
# loss:3.019
# 握年五胥萦彷佛，江歌黄着一淹毛。自知白花钓儒臂，鲜培供斋捕家涔。
# loss:2.959
# 宇得九月庆住筵，琼仙欢篱夕胡湾。吟啖铿唇磨生令，兹花破块火无狃。
# loss:3.004
# 呶朝定守回士饥，博点匡庐沸震枪。满暴问向归黄义，淹岳吹渡不盈颠。
# loss:2.869
# 序得水蕤工难沙，翠衔天味驭游遨。酒拓晴字驱潜鳄，一首一封厌淫惂。
# loss:2.864
# 觉得恋语六，过，秋妨拥花走依袍。垂迎应悔辞若翦，战觞待仁瑶凡禽。
# loss:2.821
# 轧花九月庆华筵，雕贵聪慧须娉。。雨纸不天终晕，石看遥忆故园香。命
# loss:2.825
# 模得下车暗盈披，甘棠渔病逐头非。计阁汹兀望窟舞，要必奇河耀人尝。
# loss:2.826
# 瑟蟹闽武控拍涂，弄我此咽霸游衔。拜罢真许乘酒路，奔尺斑蜍联滕河。
# loss:2.794
# 宰消由气性自茫，攘憎三触纵兰翩。菜此蒲起认奴兴，也眼私复咸蛮横。
# loss:2.848
# 岩果应罗挥牛刀，欣鸢惜岁走兰瑚。封橐棠命苏则宿，折耳只骑尽系思，
# loss:2.760
# 渎势灰社浑桃津，后旺瓜大通太。那堪槟兽抱卢头，白到北轮醒酿醒。惆
# loss:2.865
# 积今葳路香澄荫，飞策层质吼蒲牢。投到鼎州看福志，一汁猿啸醒觳青。
# loss:2.895
# 桔月但知都道照，老步清溪到翠微。噌青北馨侵巨籍，消榔待业符青咎。
# loss:2.869
# 媸蝶山残麋入长，精马呵护鲎监民。萸艎倘仆双樊暮，吕教耸风似藓想。
# loss:2.888
# 勇管灰旋陈蜜婢，鲲鸢隐怪最卷苔。旁笑巴音资醇运，戈听梯翁炼春心。
# loss:2.783
# 甘钧添骑蹄箫操，蟹瀑到袅逢兰。。域衔知天三有，插榔惠声初虫贤。奚
# loss:2.789
# 哕事但长到故涯，破营清碍如天天。遥功文韵驱潜手，此来仙集怒。栽嶂
# loss:2.775
# 绸门极桑接林垧，砌门编篱作短屏。菜甲初舒频染绿，笋鞭脍劚把次青。
# loss:2.657
# 约帆极目海千宽，破暖烟光映笔端。吟到生腔联翼指，贯垒阵风竞重阳。
# loss:2.702
# 轴雨下晴迟如见，笥艳忽看作节妍。雨露如今逢圣世，栽培兰日无。星。
# loss:2.753
# 瓠载洗涤色非它，万湾眷慕还诗穷。读目沧有曾雕颊，栽及我公不老仙。
# loss:2.817
# 疏琴闽徭还莓久，三贲灰迹鸣珠牢。万青贾瑚不敷治，故遣当叶秋萧骚。
# loss:2.835
# 暗堂三人度熳阳，过溟盛德就安吟。铃种高射么汉亮，缦枝镇死共心醒。
# loss:2.712
# 潞秋九车暗斜缪，厚，初惯入成奇。但啖乍唇星番语，未月文译洒公河。
# loss:2.643
# 沅道如根遗工岚，更榼瓜榔不深香。烟知春人夸醉犁，封夸微皇蜡语丸。
# loss:2.575
# 籙字吞旋陈霜瓜，想入偏鬼荷山祟。海妆大树铭钟鼎，争龙铁垒几沧居。
# loss:2.592
# 醅管隐象素桃津，到术篱临日深边。不是霞教白敷裕，八柯鹊种话官寒。
# loss:2.543
# 伤得微波屋万过，精困着入觉壮眠。菜是一年有笼赠，万山起交脍为明。
# loss:2.595
# 秤管隐岛陈女婢，纸鸢抵棹作在光。昆是霞吐舒无食，物产佳风输官观。
# loss:2.540
# 嘶浪题蜍入象题，口君鲁方更淹心。解知浑教倾江草，先条计忝附官麾。
# loss:2.505
# 蕤清下光都鲸恨，何术犹明鬼子悲。异清更愁终颗节，一袖遥渡睍飕颾。
# loss:2.521
# 瀑火治定苦水梦，千躠扬阁知崦。。应笑歧日逢额世，争岳蹴寄彭问涂。
# loss:2.460
# 族耳鸟味蹄巉西，招结书铁逐山中。海仑吟儿贯离櫜无空，漫出沉莽作穹
# loss:2.443
# 孱外梅柳斗芳菲，散步先闻柳儿场。惆刺童瑚长吏鼎，清时清叶共鸡扉。
# loss:2.494
# 怕怪藤脆香笑晕，会须匡庐景霜鸣。道犊黯幅回世运，故灵稳卧未老惂。
# loss:2.511
# 亩香小立香天象，振屋衔虚入南裟。我寞纸尾知无补，逼沙灚此重舞筵。
# loss:2.391
# 矜泛由击本巉黑，称下编篱作短屏。菜甲初舒钳多暇，不邦昏结不蛟钱。
# loss:2.408
# 尚阙鼻女初箫沙，呼眼欢壁聊蒸熇。铁演银输未田意，海家滋园蝶廉醒。
# loss:2.379
# 贩夜三去桃迟路，岁山枫译最深门。晨曦潋滟恰东升，一邑惠林尚留青。
# loss:2.421
# 跻年儒餐开头西，一湾跋靡健裂春。怪演东处月何竹，皇更粗营冠无数。
# loss:2.384
# 浑开觉路接鸣森，森聚斗勒加鞍鞯。雷途榕韵遮寒妻，槟常一声赛方寒。
# loss:2.395
# 砌学腻上绶带奇，忽扇台枰射鞍天。胜霆张觉人静功，守今咫时留变猜。
# loss:2.447
# 衍鸡难仙拖三簩，偶门编篱亦短屏。酋甲初舒陶染竹，笋鹂图恋逐桐驰。
# loss:2.489
# 困轩牛徭堪斗易，志驱墨豹逐蜂蛮。殊阁但兀浮垂寂，桅教普帘度野林。
# loss:2.395
# 备璃对塘逃平象，难见如戏渴人赊。散笑歧路锦蝴宴，，落奇风年棹桑。
# loss:2.472
# 撏蟹蒙帆争苗谋，治挹清涛悦纷盘。清青蛎花逢渔接，潮培长此乐尧天。
# loss:2.714
# 陌把难千都海已，熙灯饷税蓬子中。圆锐神哥千所后，一培蹴射霜何瀛。
# loss:2.565
# 濑蛇灰旋照颜东，尤片傀儡慎防毛。满韵饥人输白澜，试缈谁珓客相酣。
# loss:2.505
# 系钧单汉摘变葛，竞驱墨豹逐蜂汤。标今课骨双忠信，种山应是逐槛驰。
# loss:2.422
# 吊人良畴增凿地，并弦青宵烦鲵伺。吾侪岂手赓双传，一分败浪洵任闲。
# loss:2.418
# 漏雨下月庆华筵，老贲灰匀绿爪端。澄谋城须能鹏渡，今翠桄怅雨老浮。
# loss:2.548
# 板葛轻便蹄其手，竞载沧墓风染茅。西上歧笑桅野阔，为书当呼不睆音。
# loss:2.724
# 丰开居剑炎垣饕，追欢舟惯达酒公。天教盛德来多贼，味闻杳采耀蛮衫。
# loss:2.873
# 周瀛添叟生阴晕，槟鸣将骨客短耶。假余贾睹殊毛饱，也鞭挥回附浏屿。
# loss:2.635
# 累林虫桑增注脚，炎方台畔吐成真。澄岛黄辔原多暮，羹缈沧瓠迷瑶窝。
# loss:2.371
# 沙许各人接画襦，拈漩苍配何玲珑。却许已郁蝉翼喜，笋鞭民劚附留蒸。
# loss:2.269
# 蟠管灰旋千面篱，南术犹火如崦鞭。双拟倏教能幽渔，砰吰真是弄解收。
# loss:2.285
# 征霭沧议香苇航，情范跋扈兴相羊。无发愁随苏汉渡，曲岳格难彭悬车。
# loss:2.267
# 溉姬棕根并迟夸，误送滋培逃子藏。有米盛公来敷治，故此猿啸种家。。
# loss:2.252
# 鸜泉下涧试女婢，纸凭墨女利群熊。好日女得好吟职，依陂疑马却疑仙。
# loss:2.246
# 徭门虫逦接论下，一湾风卜焚喧评。雪浇纵离资哥左，长桑灚灂花处寒。
# loss:2.205
# 超身准语六上市，弄然棋枰渴忉深。有山不是埋北滑，相及挥骞待泛唐。
# loss:2.175
# 纵浪猊懔近坤鼙，半看槟子见摧工。破拟击童理定均，万子肥荡黄语衬。
# loss:2.179
# 锁耳时懔冰渊念，拯槎官匀腥更华。花有泉雁未柈人，调耳一螺争爪瀛。
# loss:2.242
# 准茫声乡低孙沙，一鱼黄花晚名深。极春倘有余陆蝶，潮及我公尚留低。
# loss:2.256
# 吰外梅柳斗芳菲，散步皇棱嚣节明。万节劝主岂官佃，极目鹊从总异唇。
# loss:2.174
# 锐姬棕春倾晚地，，困连江等夕鲵。凤张眩露同济称，痴培我此思节傍。
# loss:2.171
# 慰轩闽邦控碧沙，弄澄花骢沸赐华。尖竹圣药闲时节，白邑惠箫试问涂。
# loss:2.099
# 描台环结营林垧，砌偏新庐万顷哗。遥取绛羽鹦哥舞，金产灚灂享碧镇。
# loss:2.083
# 看期敢墟鲲桃色，南岁新靡旧诗忙。双清沧辔有兴志，羹院黄此动舜廷。
# loss:2.132
# 馅璃仗露艳幽纾，涌嶂今山鸡太门。遍舆耆微回三波，愿板只处非不年。
# loss:2.190
# 宁粝农祥酒箫手，筠砾渡气试超霆。相许巴头回奴处，岛闻微译一萧行。
# loss:2.183
# 堞耳繁缨谪莽上，一山路现半蛟台。芒味大圃罗草幻，争留普家说次犁。
# loss:2.193
# 飚重走光争霜东，溪落傀阁静子苔。贪番却郁持野头，残枝败望一哀寒。
# loss:2.151
# 韵今潜镖健卒张，老洛喜师上桴霞。花取绛林侵皓渡，此避頳珠不纤堂。
# loss:2.136
# 随怀夷蔗环佳眸，苍到高兽日地浆。厨十碧书着人径，未必于声遍号联。
# loss:2.226
# 笔茫闽推谪打猫，遮舍欲方逐唐青。寂到神教天三去，胆须衣顶遍再险。
# loss:2.248
# 细身牛檄生峰羊，古鱼烟复壁谷车。花池射覆秋钟治，不家涛国重欲茫。
# loss:2.175
# 讼蝶吞象心非齩，东挛化莱何阴狡。吾鹏莫沸赓多福，砌院寒山消子花。
# loss:2.167
# 老方西社浑桃津，后旺瓜麻种作帏。舆垂莫仅孤垒宿，鹿宫樊骨享绘甘。
# loss:2.189
# 主仙极桑能林垧，砌下编篱作短屏。菜甲遍稀喷姑见，檀尺一须保牛眉。
# loss:2.103
# 酿本波气性自阳，金得西阖又相花。片里明尔片豚际，逼必于子总蛮娘。
# loss:2.208
# 倪字何树廿城四，口摇墨许一夕漓。犹服乍联群臂尽，百绕翼洲渔清横。
# loss:2.098
# 斑箐农祥斗建寅，正嵌黄惯蓬南沉。海来指能么心种，灯夸雌仁是疑桑。
# loss:2.174
# 入萧交仙教瘴夸，瑶爱仙蕉赋美茸。既若汹来顶雁首，更芽麻欲捕蹄涔。
# loss:2.304
# 瀜治图草摘露沙，弄楼欢荣高知工。未年利涉凭忠脚，凉指未心着嵌笼。
# loss:2.273
# 襟鹏由气性自天，功名富贵早超然。洛阳纵有耆英会，未及我岸不老音。
# loss:2.216
# 释管题旋陈霜照，燕挹飞又展皇舆。白翁渐历红鬼重，南洋挥达愧仰蒙。
# loss:2.195
# 船着不犷林阴轴，祇望江通逐山频。花教盛识山敷治，此遣当年共大赊。
# loss:2.144
# 罴君更霜九入东，大天三岸直。神。惆怅百洋神风已，携翠黄味试膏熬。
# loss:2.032
# 谭水如十红岛过，精马瘴护为独毛。春米青征牙水明，失知已忆故华情。
# loss:2.114
# 液泉何燕平里叨，柳潮游篱作群熊。尔日春逢谈蝴蝶，花犹第尽入浆。。
# loss:2.030
# 萋霭埋蒸凤变化，教歌欢舞色深噑。万是竹槎彭堂化，广冉粗鸥遍再甘。
# loss:2.083
# 集颊添击易箫音，筠亚齿隙调琴心。入月种盏已光径，梅把安垒四禅林。
# loss:2.010
# 浩雄轻身蹄其化，入歌沧阁直息城。芒带饥背钳知观，乱院骢子遍画芳。
# loss:1.991
# 汤波夷蔗落佳境，古爱跳房舟鸿翩。铁番矶处无深开，一不起交费觳觫。
# loss:1.942
# 怪黎庶武每拍肩，踏衔载姿旧阳罛。奔出文播云是裕，绝者佳味那能谙。
# loss:1.946
# 折钧添息新千补，要见衔楫照清林。赤醉但有吹优屿，黄及里笑映伽胡。
# loss:1.993
# 欠月但化不萧篱，芒仔芒分月书盘。但汤长笑三笼指，共骨何马泼随涂。
# loss:1.932
# 君花波无倏天水，篷云新望直幔掠。方桑岂齿诧奋膴，归屿纵皆不二浮。
# loss:1.954
# 鸾叶簸头按鸣老，耆望天冰统天民。遥教尽安喷半仙，赖盖一携国知囷。
# loss:1.887
# 宁鹏莫浪终清日，分茸花根波二甘。铁马万向不榼里，一指蜈蜞一禅鼍。
# loss:1.881
# 旗颊添叟香冬交，秋拥酸前鬼雷霆。疏笑应低偕梦化，神龙相帘遍爪伤。
# loss:1.841
# 芦萧遗凉惟恃险，士朝欢校旧阴新。书若陆离诧无空，旗漫黄家此天殊。
# loss:1.903
# 拈目极凉物绩宣，笑君欢听气诃香。伊尼春年夸竞臂，痴看潮魂寒沁观。
# loss:1.868
# 璎叶烟华游如隐，笥然风骢绝涎心。雪此载茇余江黍，万长桄榔未竹惂。
# loss:1.870
# 换鹉螺隅耕可枝，每讶寒宵壁虎鸣。满种偏历辛为妆，未颜计骞附泛河。
# loss:1.909
# 垠泉何当只自谋，治到时仆山兴长。但应照尾和能田，敢亢同。九。雪怅
# loss:1.910
# 诉蝶吞象奏琳璈，朱望抵觉一当香。遥是伟年想竞素，贯将寒台为未吟。
# loss:1.919
# 笥外自岸飘杨菲，天榼大闻花茇微。一园一如僧妾避，兹潮云涛咸寒沉。
# loss:1.800
# 康储烟出结绸得，大讶身税静劳优。此汉曾同僧舍化，广颜同此乐尧师。
# loss:1.874
# 迈泉下涧三尺波，吏院没去保寿眉。十头孤鹏施，耳冉登民不地星。万红
# loss:1.871
# 牡字题马暗霜见，白，身税涛标雄。稀眼十年何余泣，笔驰呵家扬沙沉。
# loss:1.861
# 躔开葳蕤香生里，分装急虚入山船。澄阳破谱循田传，送看大处野解翅。
# loss:1.859
# 杨分贔雨拄投轴，羲毂黄壁就敢眼。吟啖槟唇兼翼春，回帅镇玉鹦严吟。
# loss:1.854
# 乘欲左汉破林垧，可下满岭豺深香。大居竹书籦知补，九食灚山享虫来。
# loss:1.956
# 訇蟹题樯霜尺波，为眼于瘴叱子人。圆阁乱髯黄柑指，也鹂熏恋野行收。
# loss:1.872
# 鬘管题当教有谋，仰凭长溪如群瑚。但马将哥清远怒，颓飙如水重仔肩。
# loss:1.957
# 躠月走吞成四曛，雾锁羞子磨楼鹅。殊官乍唇自公晕，奔盖盟齿联凡民。
# loss:2.022
# 赞君小化奏琳璈，悬出抵掌接青浆。宏明初笼知老暇，一到真尽牛浮明。
# loss:2.001
# 浇榜乘观姓氏先，文章由世一一年。书淼背沌天三篙，气窜强蛾射壤歌。
# loss:1.910
# 顷萧高森接林垧，砌下春蕉兼鹿。。赤魄暮垒淡盘来，踏出平槎争分涂。
# loss:1.938
# 萱管灰旋千萧新，万挛荒儡到沙奇。荒汤几骨叫乐泛，砰好涛声无云忙。
# loss:1.918
# 櫜璃对峙锁孤舒，厚隐合配飞雷然。番若骇遭传金鹿，一时无樯赤王吟。
# loss:1.969
# 浸好三雾复迟见，嶕生敷骑还频搔。番锐浑向行此令，日云光叶一淋骚。
# loss:1.999
# 僮色虫极开其熳，曾山风霞接解新。脐与北结雨多暇，携得深人有千花。
# loss:1.917
# 争蒙多床侍释迦，暗疏岂鬓旧知穷。非酒几树天茶贼，奔掬林分民语时。
# loss:1.997
# 皋在极蛇并吴垧，砌下宜望瘴低疴。番到客节持倾意，回家晴死保梦此。
# loss:1.936
# 赘字灰旋与霜光，朱营绕重如水长。萸酒年年常醉客，争雄壁垒几时初。
# loss:2.041
# 钳蛇治吞九水东，酒茸守向拙相苔。双犊省抱远野楣，万者萍人达回闲。
# loss:2.054
# 屐目极结接林垧，砌下编篱作短屏。菜甲岐稀凭衰手，戈爱梯村天蛟闲。
# loss:1.930
# 菩闪左无倏笑早，更来吹写笑深花。有无有是谁兵金，雕鸠何测重舜廷。
# loss:1.953
# 着影情构鷁注先，欣然迎饱乐并长。剧篷秋帆重额虎，愿飙谁魂有何舞。
# loss:1.913
# 帐余其蒸蹄箫肃，炎人乘片见荜残。三知风色闲圣泣，载看从瓠重草肩。
# loss:1.973
# 掏壖题腊荐隐瓜，治挹着掌展于奇。但到利佞天生名，海有应青共解唐。
# loss:2.061
# 槎耳腾恩落打猫，文说志化君阳非。香飘岛珠陶钧匏，管翮势抱超腴口。
# loss:2.322
# 沾却喧彩余荒涂，井章台林一峥东。浩亭握手色美醪，石将樵蛾赴战场。
# loss:2.083
# 宇蛇洲空迷醄醄，仰乳惜掌不好熊。赤鹏陆回雄沙线，到到应集盐自现。
# loss:2.043
# 康佛洲弹可唤饥，博望一叶斗雁茸。鸿雁已涛叫人蝶，士院雌羞几壮哉。
# loss:1.941
# 矿泉是涧会能婢，纸鸢官掌为壮哉。来乡万初先巨阔，晚围未劚尚留奇。
# loss:1.790
# 蜜余寒姿菊羽扇，炎化此蕉软游遨。厦鹏岂髯兼遗颊，管花文蟹问福花。
# loss:1.902
# 惨蛇吞象奏琳璈，溪，赘樯万而迷。遥是盛折知天夜，波叶空屿不淫微。
# loss:1.803
# 酿施群推乘澄力，珠渡墨质凤蒲喧。木张槟拊能沙鳌，万犁嵌榔知社人。
# loss:1.720
# 菰佛两粤重鸣饥，濆沦澎阁忽摧亭。残飘甘白正卢堂，腾应应为天共脚。
# loss:1.709
# 伶蟹题旋不象新，还眼万别叱浮枪。敢笑纔肉白呼尽，女耳民马铸姑尝。
# loss:1.679
# 寒无宜去迟绸荒，散圃王慕更象屏。奚囊万萸罩缓挑，畅诸琼竹争纵猜。
# loss:1.782
# 女耳由涎挥渐粟，蟹棠墨圃还英耆。家甲频稀村舍少，未指青秤把虎翅。
# loss:1.747
# 沿裳直踞碧横亭，鬼醉画饱吐青莲。此教盛埃浮二官，至夫蹴父甘遭真。
# loss:1.682
# 骧字灰旋照颜色，踏腾官莫拟丝吟。清洲劝历么前寐，黄出黄槎那魄林。
# loss:1.715
# 嫩寂波甘可拍赋，如玉为骢尤伤深。海十甘向秋怀重，奔窜富觉年壮堂。
# loss:1.717
# 拨蟹题影教女婢，纸鸢画九天欲香。入须苏髯任辰线，放腾登鸢扬红旻。
# loss:1.645
# 殷他春春度重辙，精醅狂掌照天层。晨知扬辔看天补，扶缈初诗山云国。
# loss:1.688
# 庆竹盘法斗瀛堧，到首喜寒西珊官。台甲频稀村衰俗，此避稳开女次地。
# loss:1.631
# 缠里虫畴斗凿易，欣然惜饱走唐心。既和族类臻饶裕，秫属遥风在昔筵。
# loss:1.606
# 招峰准仗六丁力，口衔载勒加鞍罗。三知似却近紫处，回芽篇边尚息舂。
# loss:1.705
# 韵望清因溯去程，蟹林客国届深深。一怜老时说翅观，梦钥青生半城阴。
# loss:1.699
# 血鳌准儿未拍痛，三隔磷靡斗涎行。满家绝姿争田腴，喜心射欲势吟蜂。
# loss:1.650
# 人受清破沸浓光，奔腾五着谢珠吟。铃家播得闲卢收，金及穷山一大重。
# loss:1.646
# 拥溪喧传姓氏先，文章此庐吐为频。雨笑却随咽梦重，更瓣未香达落低。
# loss:1.659
# 吸泉题社榔头中，波，齿桑惜姿行牛鼎。荒月烟巷金把地，相报未安未分
# loss:1.659
# 意围何山争隐东，溪上傀儡谢山车。此朝一限映伽春，阡极一声面膏熬。
# loss:1.681
# 焦蟹题旋椎象光，东风吹彻白登城。一与岁书愁雨小，云隅丛人数回翔。
# loss:1.672
# 和箐儒剑初定痛，鲲听连气任浮挠。积霆沙齿鹏奋身，涸鳞陆死盐田肥。
# loss:1.716
# 庐寂花露能斗披，隐上高谷一崦嵫。万知西教双行高，笑月猱采渡蛮桓。
# loss:1.768
# 悠竹盘镖终铁客，鲲身官临亦壮伺。赤蛇逆浪掉两手，只船放赦在丈廷。
# loss:1.767
# 遍分莫女悲兰茝，正色宜令幽谷藏。阄宇骀明随无口，封奏清皇牙逃会。
# loss:1.646
# 堕门宠蕤渡盈奇，绛文云去避美遨。一乡万诉一峰冰，栽发如水一未官。
# loss:1.622
# 空色山道镇南荒，亲到鸟鬼肃双搔。男到鬼沌鸡黄出，白谷未舒贌盈香。
# loss:1.580
# 赉清吐吞成在照，施余不象白天云。蒙是榕须遮户罗，鹿宫阵身故巡浮。
# loss:1.684
# 緺香觉极驾载逃，神渡齿勒是家逢。敢年船投孤轻宿，安光清处重提微。
# loss:1.697
# 挑消狙犷林阴斗，雕母泻间市井喧。酒张风何谈言定，谦得猿国易日深。
# loss:1.712
# 斜鹉风雨拄坤轴，羲毂轩轩欲英搔。香青者射唐攸食，信桐蠡须咸交人。
# loss:1.705
# 滞当天山绕儿知，东篱种顷巧头行。巡风生幅何伏护，樵移渔父遍遭烹。
# loss:1.699
# 髀叶出空不荒月，也赤沧护夕虎蛮。夜借茱萸贡柏少，彷和铁父尽桓桓。
# loss:1.599
# 漫却风风雨雨微。篷茫犹余半头中。遥甲消菊鹦黄禽，叶洋消德铭蒙香。
# loss:1.584
# 畜蛇吞重酒如三，扶摇身龙拟微时。佛云浑佞成护持，樵头弼歌碧风来。
# loss:1.653
# 读浪声乡思已禁，一锁结彻化泛中。大有出节未百滔，携得新箸共欲花。
# loss:1.652
# 盖耳周叟生家空，槟榔针林忽南端。海说平声秋生小，朝画仙情女画浪。
# loss:1.674
# 境年涯止远农长，遗醉谁饱傍渔牢。既喜沙涨自三篙，叶点相槎争青涂。
# loss:1.618
# 零外郡邑祇粗安，鼎立僮化不用屏。遥说何头共柏滑，无华应洲不春音。
# loss:1.706
# 嬴蝶吞象素桃鸟，骚里直累羡子低。宏秋播向金江际，晚里积处在名行。
# loss:1.628
# 曰管灰旋万象新，纸衫连月如战鲵。花风声是三多有，痴往杳茎总东移。
# loss:1.580
# 爝蝶金底都铁宿，三，清知足郑悲。自风唤子避，，颜齐同此一思香。极
# loss:1.586
# 涓蟹绿涧三尺波，万钓黄香旧节老。巡酒苏髯谁三暮，银得沧为筑清作。
# loss:1.660
# 伍管灰旋万象新，萧来吹酒见无赊。百年内得留提老，酒有云时大能未。
# loss:1.563
# 疏怪多命侍空向，一范先理问明逃。澄衣应郁来地晴，一声真羽霜天时。
# loss:1.617
# 彤字灰会还象新，番风新鹿满天香。金是有办晨提鳌，栽长麻腊不沧星。
# loss:1.754
# 长饮秋下八入开，嶕。寒病清而留。但阳纵州回勋业，金丝佳家减群归。
# loss:1.866
# 糕泉题旋照雕照，骚沐登培龙叶篇。可廉逃星几防裕，秫堂公人面摇联。
# loss:1.638
# 培身征星剧建寅，管见路世客于晖。怪向枯语凭可地，搴云妍贤挛自夜。
# loss:1.628
# 陋管灰旋照颜迷，南辱大气波大万。萧人偏竹来百老，踏窜拍旭丽旌墙。
# loss:1.691
# 肃鱼怪练碧贝叹，沧溟踪鬓苦漫优。铃生如巷扶梦处，战今环凉冠异葩。
# loss:1.625
# 骈蟹隐当见自四，扶君此味悦监州。双廉引有人折白，守月樵营鲎头胎。
# loss:1.631
# 辈却时翻世民萤，赤怀谁起故三嵘。伊经归人皆得有，一叶庭遣击泛歌。
# loss:1.559
# 家柔出守诛唤好，回舶无月万蒙奇。旁载万山车回妇，千培昏香无所殊。
# loss:1.546
# 朔管灰马入莽鸟，口衔罔市吐云频。天里如是三气长，为问墙开争回未。
# loss:1.562
# 触冠腻新横恬甘，澄转衔此问不然。尖许烟年非清客，姿恩寒家遍钓堤。
# loss:1.570
# 京管灰旋北头林，宠里路在人。溪是鲲惭书远考，鹿耳烟影添朦胧。百篷
# loss:1.536
# 龙台若无倏若有，功须身入蓬壶林。佛阁但齿铭钟处，光鼓各徧徒安墙。
# loss:1.525
# 阻蛇吞鱼鲲浓色，高将扶儡早皇吟。十月绿毛烽人见，刺桑蠡作渐成斗。
# loss:1.400
# 月油鲸歌昙求醄，香上五儡见诗同。双到倘沌归论颊，芳陂谁洲影疑仙。
# loss:1.466
# 奠月鬼吞千鬼新，东望路风见解淳。天物从镇解雨小，缥花声望却华仙。
# loss:1.502
# 醰清走马到萧篱，芒仔芒分茄茇支。换山内优炎鹿径，石烟终轮醒火觫。
# loss:1.533
# 伫字题霭碧城水，万点斗莱何知留。方。飞年花生归，拓梦独箸附瀛香。
# loss:1.551
# 罗身舂列侍雌伏，文瀑高怪瘴深深。香魂怪尽甘钧秋，一浦应洲神辟今。
# loss:1.532
# 筹开觉路香生履，振落天花色染衣。更上一今月华泣，灯捧渔梅驻三家。
# loss:1.509
# 眺嫌狙犷三初生，鲲醅初兽此天嵘。浩亭握螺争芳路，但田耕徧徒不流。
# loss:1.623
# 闪和鞭晓车复斗，一山无气焉虎久。雄兮兰兮理则均，强胜佳身不老胡。
# loss:1.599
# 君学难处似水，，天狂水月由曨。番轩沙化臻此成。极目泼涛浪劳谙。厦
# loss:1.563
# 屋本由衫挥羽扇，炎上醉分客忉忉。离天僮抱木生翠，信岛空处留公廷。
# loss:1.564
# 灿暄渐后终氏渡，槎食仙间闻沈长。路知乞月闲吟职，高陂瀛洲耳渺身。
# loss:1.646
# 呼开喧传姓氏先，文章台阁吐并牢。酒语苏悬不多仙，齐花沧忆纪攸未。
# loss:1.564
# 攲蛇吞象浑硜津，治然客觉客红羊。百绮不南频竞渡，相家猿啸度日层。
# loss:1.511
# 魛泉下腊荐霜柑，缫连迎中柳名赊。天年马海何天深，一来闲尽蝶觳觫。
# loss:1.723
# 郡箐儒餐初定痛，萧挛无听统成鸡。阿书歧头罗升女，潮听桄公秋老篱。
# loss:1.651
# 行目三碧游人见，闲潮一木舟成残。解椒一人夸禅果，十含风肃一禅微。
# loss:3.158
# 淮裳直踞海料茫，瑶过回里乘鹊枪。惆城暮姿理野均，海须强人一自鷖。
# loss:4.178
# 矣传未难千再它，濆溟澎德见楼多。极龙但箸判耳麾，一胎晴忝尚英匏。
# loss:3.284
# 未菊璚角碧牙镝，博嶂扬叶两精瑚。堪兮金迹不半治，愿衣渔河可为禽。
# loss:2.733
# 舄姬遗两半明市，瘴潮轩濞调毋然。夹日琼射林光贫，逼春遥筒与腊筒。
# loss:3.376
# 精霭添叟白能晕，白云鸟阁近作琴。拜随应悔归时酒，悔枝一生把依犁。
# loss:2.982
# 葛溪由路性生履，簿留泻质蓬浮莲。海说一造凭官鼙，晚浆民箫问求星。
# loss:2.655
# 狗治鼻推双北宿，安眼新帆隔壶工。十罗一卷奚在口，携驰黄此或棹花。
# loss:2.389
# 略冠腻武远斗青，郑宅盛校旧水多。澄谋汉遭不中桑，白刃酣瓣鹦头翠。
# loss:2.266
# 冻门宠命物林瓅，维脚如妨下成天。面今沉尔半再指，尘鹂疑恋逐自诗。
# loss:2.059
# 波罗东华桃罅开，偶崖椰篱作明猱。四汤矫科罗黄渡，折食壁骑尽为尝。
# loss:1.864
# 范寂红齑禄料宽，高然岛江两壶中。参云斗输鹏潜甘，铅椠舌帆属自好。
# loss:1.875
# 报钧淑涎良余粟，宫潮衔分地碧晖。一笑歧功资大镇，死他蠡测与兰猜。
# loss:1.841
# 宇蛇轻敲千非漫，文衣王虚欲沧亭。淅息乍觉群息屿，盈听从村遍逃鼙。
# loss:1.798
# 鞅闲片嶕黛螺黄，银蝶志村落象狡。男儿沙仅入蓬平，阡片张放弓再櫜。
# loss:1.718
# 彷知散合自难管，西鱼结转苦鼓浮。竹阁文悬唐垂秋，缦首应遣凤风今。
# loss:1.701
# 庶台若锦黛千滨，朝舍烟光映笔端。吟沥城去遗鸟福，放戟谁槎原方茫。
# loss:1.649
# 粮蛇花卷桃非佛，马君飞气问不。。异更玉藤沙淡航，赖出民虱傍海翔。
# loss:1.667
# 状帆觉路香生履，振落光花猿清枝。丛目沧桑浮乐重，缦山应人共大微。
# loss:1.723
# 翔蝶含弹布琳璈，奔交皇莫一楼自。遥鹿文尽铭钟鼎，故分篱土共蹄涔。
# loss:1.668
# 采渺由气又水申，叶洛衣冠旧母心。怪月政澜罗号传，敢鸟秋里月云肩。
# loss:1.597
# 墄字好知只子谋，鲸凭此市悦监州。莫螯浮抱炎荒长，影洋保赦同重愁。
# loss:1.550
# 奚得恋栈心难白，祇调急溪入淋留。两雾鹿语白三宽，黄缈粗蟹有壮哉。
# loss:1.555
# 絺管绿成到处重，柳摇身莫暮欲涛。白从月人三雨酒，族驰常榔几和星。
# loss:1.557
# 勾裳直踞千八上，濆篱估拋草人同。此教子屿片随仙，好陌心韵西唐师。
# loss:1.506
# 科身由气性自天，功名富贵早超然。洛阳纵有耆英会，未及我公不老仙。
# loss:1.483
# 罔蝶散残世入知，万散到闻疑涎行。沙余矶露抱番民，放雄烟影添朦胧。
# loss:1.438
# 灊蟹题涧教地谋，想摇此溪长盈亭。此家不月逢额虎，十书挥戈仰再盟。
# loss:1.498
# 黝蟹隐涧只尺岛，日丽皇途騄駬鞭。雨棹迎人千时寒，微来昙洲醒觳觫。
# loss:1.491
# 才承鼻恩双箫葛，呼入此蕉万云。。蚩蚩投瑚远草重，叶者张弩新当寒。
# loss:1.466
# 瓣门觉观白边航，分林理子两浮春。黄是浑悬蜃窟怪，漫春背履玉黄考。
# loss:1.483
# 屈初螺车沙凿镝，并入飞起舵民停。俗仍汉献原鹿客，送里时樯未时深。
# loss:1.463
# 椒得得车九离披，隐思厉发绝九春。如带无散初里口，鲸驰真绝驻不林。
# loss:1.346
# 涉茶甘畴耕凿易，欣然醉饱乐唐虞。饱啖槟榔未天贫，扶不空忆故园香。
# loss:1.464
# 泥鼓鞭晓碧天重，地指扶光见散宜。天知泉向闲吟獒，海乡应竹重子林。
# loss:1.467
# 催消驯莽颜变饕，追欢番咏达金从。新明当人初把臂，鲜生镇浪是冷台。
# loss:1.475
# 珍成觉路惊盈去，绛险王饮加子低。宏秋播翁来敷业，万竿烟鲤国蛟可。
# loss:1.441
# 疾越贔屭拄坤轴，羲毂如蕉绝游遨。厦知酒腔曾江獒，八漫斑心入巨思。
# loss:1.382
# 峭蝶吞象不萧齩，三岁种冰下作亭。双孙汉化原田膴，指歌清诗兴。来。
# loss:1.412
# 摋蟹隐当只蜜婢，纸鸢画就来日年。不魂怪尽喷折雾，更里夸胜此层堂。
# loss:1.431
# 梨兢风灯远度萤，坐拥白阁纵无腾。轻星倏客万桑重，日山雪波有日开。
# loss:1.441
# 跋泉题涧斗峰谋，千步清溪子翠舆天五涛山垂处华，但问应马碧雨空。怒
# loss:1.411
# 学耳由香性自天，功名富贵早超然。洛阳纵有耆英会，未及我安不胜惊。
# loss:1.404
# 徨字题涧暗象婢，纸鸢画麻低闲心。海笼怪屿琴死櫜，齐将入从心事重。
# loss:1.352
# 艺管灰旋入呼鸟，骚君中方焚鸿犀。巡骇铿訇空之阿，樵头衔身渡英髦。
# loss:1.403
# 觉烟恋绕结绸缪，翠羽身茎出诗篇。澄星露手将翔中，旗常林避不飕颾。
# loss:1.373
# 崇帆为十六岛过，精灵呵护烦天公。荡缨纡回判沙线，鹿桑诗家投忧猜。
# loss:1.422
# 颂屿鼻遭扬其葛，的砾渡恩赤前成。香来使教未野小，死括从河色界更，
# loss:1.400
# 毫渺岛屿心巉岩，蟹舍渔村落日衔。从笑七海三云重，鹿雄黄许细三东。
# loss:1.403
# 萼壖残涧教花梦，亲到西立谈不山。。白露献莓空贫，要里空幅寒客堂。
# loss:1.465
# 鸜泉下涧暗女婢，岁鸢清没已领行。满长从金已故暘，东者蜈蜞为睆涝。
# loss:1.428
# 浩马添遭破女工，竞驱墨惯紫榔盘。沙阁汹溅顶踵湿，白长风驰洵首观。
# loss:1.394
# 屭管灰旋荐颜光，蛮色隐风到愚淳。乘气南露逢海节，陆潮心泼开晶窿。
# loss:1.404
# 用觉新路惊蛇渡，螺蟾珠村如水长。聚雨知滟菩提果，须妍雌义东知星。
# loss:1.415
# 溥泉隐涧拟有市，治挹清里兴已酣。采域旧使投芳草，拍眼怪语重云节。
# loss:1.359
# 配蛇轻敲北非绮，客沐齿长似鞍花。大事难尔倾辰髦，纵月应烟千如菊。
# loss:1.439
# 煨蝶吞残世远开，万篱化月老駬寒。独拟亭教千道水，近发鲲觉尽辰唇。
# loss:1.416
# 缸清走马到萧旗，芒仔芒谷自古羊。萸孙击童童冈头，巡月鸟，元儿冈衣
# loss:1.380
# 讲岚由涎嚼农葛，神险一象授驯神。非得纔命孤田信，敢信青名取次刊。
# loss:1.496
# 曷蛇吞象不巉齩，东，东马万而威人同。。雨空辔有多志，愿更弼气重应
# loss:1.435
# 悁余何樯只久婢，纸势难沙又山独。敢螯知烟能随近，栽报昏此傍瀛洲。
# loss:1.553
# 亥蛇得残清入梦，鲤人舟历见风同。子知裹折曾无补，万教丛教争明林。
# loss:1.627
# 少身各仗乡音熳，一山隐现佛属非。怪魄好建烦酋重，未得相洲未腊云。
# loss:1.674
# 砰得下车政绩宣，甘棠载咏为转羊。遥青秋人破时应，栽开谁线雨时仙。
# loss:1.668
# 弓马由味嚼莽榔，竞庸龙岁启沧香。真鲨老意菩提果，拓供如山共红驰。
# loss:1.685
# 漫雄由气性自天，功名富贵早超然。洛阳纵尔不伏脚，争漫寒如成舞筵。
# loss:1.537
# 膝门高结接林垧，扶暖沉步一沾尘。赤拓竹手耀醇处，岛盖灯徧徒如狂。
# loss:1.384
# 耘泉下涧教女婢，纸势画马悦监州。犹廉倏处留雨升，翠涛长气为唱重。
# loss:1.477
# 诧峰攒隅历北枝，苍翻绕采舵壮哉。嘘青一音雁心现，海来花发送清开。
# loss:1.513
# 鑱清走马能鲸瓜，骚古君仆作低帏。轻水南腔色百，，华头琼微日家。昆
# loss:1.520
# 蜂声宠命远同萤，使看潜历见桅低。十甲频随尽生扬，白鱼佳人减却愁。
# loss:1.552
# 熏门高结接林垧，砌下编足作山輠。极是一震遮户幻，齐古黄生傍云海。
# loss:1.523
# 臻得下车政绩宣，甘棠载咏为英哉。菜甲更得车翅妇，回立安俸重丈星。
# loss:1.379
# 粤身剪口划斜脚，志然醉国客喧半。非萼白年天应地，曾长含牛霜用儿。
# loss:1.356
# 扶萧东雨红脚念，马母凌虚入群烟。但板逆浪掉绩头，消花新解流虎城。
# loss:1.336
# 主帆三雾复离化，赤饮鸣伯聊相鸣。。更揽辔知公志，一遣长日何人任。
# loss:1.353
# 元屿鼻恩扬光韬，，潮三洄色虎本。丛绕我路无同晴，一开琼土易楼沉。
# loss:1.294
# 师歌声情首若昏，忽书泻山一鲲长。天轩从镇安留力，曲红琼声草纵时。
# loss:1.292
# 压萧番西渡孙鼛，偶携无叶景粉春。到窗万队未曛高，争花朱履又纷鲵。
# loss:1.234
# 圭泉下樯心喧波，吏鸢平水年独天。雷长一幸公卿险，新谷频怅悟题青。
# loss:1.293
# 熹蟹下涧三尺波，月里飞涉日如花。烟今无数秋清口，为冰惆香陈城天。
# loss:1.266
# 强桐狙梯点亭听，一味一里驾相久。雨家甘随休洲兴，调是船回一枯堂。
# loss:1.250
# 矿泉知涧故四波，雾锁清从一监民。萸廉香照飞临泉，砰谷保心天草节。
# loss:1.256
# 饕冠闽邦堪上馔，愿乞骸古如水痴。从来利涉凭忠信，笑指涛身晓莲青。
# loss:1.240
# 熳帆高结接林垧，砌下编篱作短屏。菜甲初舒频染绿，笋鞭未劚尚留青。
# loss:1.256
# 道他遗车承恃市，熙人触木受来静。鹿廉催有成时篙，鹿耳何螺北逃平。
# loss:1.275
# 髴外自道飘杨菲，今里清发已山忙。谩知子尽林鬼绿，遥好涛雨倚槛听。
# loss:1.261
# 修身准彩我何外，篷湾扶属似日非。气余盛焰死染春，陆窜清思初黑新。
# loss:1.263
# 垧帆梅结接可市，一连无时下沈哗。此书扶似侵舍草，笋围从帘蜡时仙。
# loss:1.258
# 短承群推凤兰易，炎身古色语染衣。轻罢只取珊今中，旗听勋河冠入时。
# loss:1.322
# 励字隐涧暗自谋，难见方迹一天老。解方帆字营微细，久见谁为天生宽。
# loss:1.240
# 畀蛇吞象清象尘，神书高马旧天公。四廉风道添鸥近，入到同叶未欲听。
# loss:1.275
# 灾蛇吞象奏饶津，妍鸟鸟里风水年。大知鸟粮影杯拙，彷车弼翁清一口。
# loss:1.263
# 四季山西游晚渡，穰圃非师达入林。共当珊惭子沧翠，竹处心处傍妾飞。
# loss:1.203
# 爱海烟映已岛风，也国炎长晚夕晖。乱暴应影秋天在，采听蠡然前兴民。
# loss:1.278
# 卒蛇吞象浑桃津，后旺瓜麻种花滨。百年裹粮漫回芽，姿所香然秋树后。
# loss:1.234
# 辰门坏土长有，相古舟冠共昙鸟。到天睨用一天气，未往杳茎行时方。芳
# loss:1.230
# 旱璃金学可牙方，软女销咏醉无残。昆青一年真春来，秋是萍踪一瞬民。
# loss:1.267
# 虹人草叶列相堧，三天然波胜太华。满十神区惊洲信，爱椠力鸥一仪难。
# loss:1.237
# 蛎蛇吞象不须齩，东天吹酒直子频。与迎冰肉笑远黍，绝食烟风夜双筵。
# loss:1.197
# 凌耳交后竖横沙，的砾似水愧南深。铁阳揽除炎卿径，残枝败雨拥大随。
# loss:1.195
# 差羽腻沈绶带长，不分磷年健语牛。命暴雌童亦花去，客龙计忝赴不家。
# loss:1.196
# 碊浪四樯爱在四，瘴摇此碍万盈九。动上神传金雨暘，南者羲味勒日年。
# loss:1.254
# 墓蝶轻弹施孤广，我人风方尽舞空环年头不峡里，金驰为轧破虫吟。一发
# loss:1.277
# 席更葳蕤红盈满，鸣怀新蕉荷照包。铃青唤起狂奴出，晚谷民云想摇官。
# loss:1.240
# 湛蛇灰旋天萧方，雾儿罔月万水忙。萸拟亭首双双头，长谷遥思秋由知。
# loss:1.254
# 许鳌多床侍释迦，一雨眷片见诗亭。他艎独抱有勋业，一鲸王卧出红林。
# loss:1.221
# 础蛇灰旋万象新，东风吹彻已心成。好飘突兀荷兰筑，纵到同洲砧前惯。
# loss:1.250
# 罕茫狙犷渐恬熙，簿杰巅去下社师。万稀春年长已阴，神鸠明火蜡地丸。
# loss:1.271
# 瞳鸡鞭针腰束绦，番帅鬼木瘴分琴不。一带玉荒同战指，万里心园耀浆歌
# loss:1.270
# 聪裳鞭踞自峰东，西湾晴前鼓画罗。盛迎旧除罗无现，但食鲲玉扬能传。
# loss:1.196
# 贤今宝剑鲲光韬，弄楼如蕉避人腾。盛亭眩然偕乐利，到声涛年一枕傍。
# loss:1.216
# 舒岚两女双千林，淡门瘴暴逃涎浮。胜阁苏髯虚巨美，鹿括吟化泛烟尝。
# loss:1.227
# 寿却渐蒸鲲荒中，愿空轻酒叶当曨。面年倘尔呕防成，故开遥望寸高来。
# loss:1.222
# 陋管灰旋万象新，出点登贾平英靖。奚海何巷金白里，一山真羽种浮仙。
# loss:1.211
# 错开坏土惊已愁，飞落长世客夕已。迟蛇逆年三由赠，奔窜赤梅浪号河。
# loss:1.210
# 渊耳宿缨量入东，下知富瑚尽幔长。寂寞浑输高碧补，飞目遥湖月壶觅。
# loss:1.196
# 鹜门三圃结离披，平里不瓢新。不味得队兴春气，界英常味播光民。标缨
# loss:1.197
# 拂明宠辣耸子溶，纨扇罗里旧毋挠。他应张齿知奋公，重欢桄顶争鱼红。
# loss:1.183
# 言网原上鸟葸恙，蒙茸瘴饮晚短良。雪阁一山驯气际，，天天成寒公沉。
# loss:1.252
# 亚开觉路香生履，振岛衔载似回輠。信雪秋震清食人，缦蝶一须争衣来。
# loss:1.210
# 勿波破卷终自枝，淡到拋绽费精枝。雪片佛客破为意，一叶云诗重欲夜。
# loss:1.229
# 臊清走蒙与绩鸟，潮作于喧玉初苔。贪城发藤迷田鼎，砰鸟琼城易出移。
# loss:1.273
# 据门高结半鲛叹，踏船墨豹未出留。楼酒贾牛蜃淡肥，烂信寒轧草虫吟。
# loss:1.253
# 阖鸡攘千无事西，金台理楫乌鹊栖。满张云帆遍济猜，螺儿挥露尽公评。
# loss:1.276
# 门朵红蕉簇汉饥，更舶竹燕一唐尘。今里深射醉十现，信产寒家抱钓堤。
# loss:1.285
# 兆蝶吞象不小点，飞仔新译洋岸新。开乘鹿字长护艳，一教同流凤水今。
# loss:1.307
# 淖字灰旋布女照，花山清闻大。地长老人君水壕，地天空烟一如云。道知
# loss:1.319
# 沛寂山尽横霜育，漫酒书入如中曨。他年斗尔征暨静，，不船风山棹。敢
# loss:1.389
# 偏萧风雨度重阳，匹门罗子乌紫牢。沙霆逆树清气里，谓听黄家第旌麾。
# loss:1.481
# 桴蛇声露石鸣青，忽钥隐堆拥荜风。解是明蝇垂翅澜，鹿胜烟影抱雨来。
# loss:1.443
# 媸蝶浓市锁酒累，治落飞口志浮蛮。王笑鹿悬光无动，白叶庭人为宦罗。
# loss:1.332
# 拜耳由涎露且里，博身万风两雁空。鸿音渔联回饶治，来遣当下变古观。
# loss:1.596
# 敦闪异蕉惟可市，目尽轩理乘摧成。佛家五牛吠无吏，万花情叶尽云层。
# loss:1.414
# 广残若仙倏若空，瓮门叶传白窥毫。奚囊频丑成紫义，丹床蹴寄彭头铁。
# loss:1.448
# 婷蟹题社会象力，安亚高咏鲸游耆。满生新帆本金头，转绕黄为丽不枝。
# loss:1.478
# 茅翩把袖自北呼，文章书临及相亭。身清老去耀余尾，痴颜涛石争疑仙。
# loss:1.404
# 款裳射虚重澄熳，庭无犹开客沧明。。更海却是空图，包捧骢屿死兰平，
# loss:1.391
# 稠门红凉已感叹，石听华未落辔羊。一令一头迎海宴，未缈炎茎洒异葩。
# loss:1.604
# 头发匹练云偶得，濆沦澎濞日水鞭。厨笑巴音回布急，此来涛贤随济笋。
# loss:1.598
# 若音直十海若路，也中飞拍乌鹊栖。盛喜汹溅顶踵湿，悔汁脱壳笑香时。
# loss:1.432
# 曷君得国清无新，影锁采彻现袈裟。怒平鹦有闲初水，称英只河介回虹。
# loss:1.336
# 藏嫌闽错心红家，萧将平庐满洋低。此朝射丑长节矿，回山鬼子共净民。
# loss:1.262
# 白关仗塘歌女客，细衔台外殄鲲鲵。飞兮云皇残兴在，消觞各作细伊咎。
# loss:1.345
# 蝶马由空性自天，功名富贵早超筹。洛涛几柑蝉随已，缦心只吼种度吟。
# loss:1.259
# 易峰攒敦六孙鼛，偶携台笠涯迟浆。御思一处无初臊，瘴鱼平槎试气曹。
# loss:1.356
# 伯身繁袖自新凝，目送一声映人人。漫轩天名入清恙，由题扶茎幛夕东。
# loss:1.384
# 忤清吐马到萧得，东家化骨若诗輠。菊是日意恰地升，皇见登羞又疑时。
# loss:1.547
# 凝西飞社引变化，将见高娥疑漫纹。年作万饮随鸟阔，万山应园有用台。
# loss:1.585
# 偿璃未前似人省，不风起转腥跻牛。十施岐鬣闲舍义，樵龙恒航抱画师。
# loss:1.714
# 剽浪隐成到在臼，攘邦出樯叱魔祟。万首矣蝇图者泣，天外遥帆浮雨员。
# loss:2.005
# 上台极目到难叹，华传拋影旧诗寒。微魂气道籦兴先，故蛇共卧不纤颾。
# loss:1.837
# 眸得高车向鲛念，匹衔编豹安青惂。胜地榕须遮绘碧，拍丝未霭争阳犀。
# loss:1.634
# 逊市得日争阴春，三南苍榔已边同。怒轩栉影同樯我，一得脱片晓目横。
# loss:1.560
# 贵东吐邑祇粗重，碧草蓬冠荡回祟。昆仑时味从乐幻，收得随解柁海流。
# loss:1.499
# 瀍蝶未首拖久岛，大朝烟色健辔行。满落神微多初发，一发不花一邑铨。
# loss:1.623
# 叟蝶花残相自席，门穰如年晚浮图。鲲懒汪水罗碧壕，阡陌杂涛浪时山。
# loss:1.682
# 久帆盘祥终已韬，弄潮时戏纵兰哗。台带似鹿知吏实，故环鸿戈雨哀嗷。
# loss:1.528
# 委月吐马不萧哭，南男赘蛟暴爪鸣。花一篱随黄奴皋，秫点桅槎击壤中。
# loss:1.381
# 忙枝北目无天宽，卧灵烟护辨盘同。中得秋银醉为台，就有烟子认天来。
# loss:1.326
# 辽临灰旋天象水，也风风气汗南来。开丛一南不半亭，白长照土重纷星。
# loss:1.265
# 茱浪隐樯北丝客，蛮史登棱为夕毛。但春门巷为虎功，衣钥应为因云频。
# loss:1.236
# 绫清万年游二谋，马锁清溪一禅收。两今当台天榼老，高有天樯关头箫。
# loss:1.241
# 爝蛇未路冰隐路，散辱无阴一翠独。霜叶猿起休将觫，开是灰之脍鱼村。
# loss:1.149
# 谓开觉人三若森，男落秋景落浮年。解想晴年成五愁，即耳槟垒扬姑香。
# loss:1.107
# 萤嫌神武自一水，别湾眷阳手霜华。气是风色谁拘金，梦培死前白丈地。
# loss:1.140
# 促门罗畴来告凶，扶蝶金光妇古枝。更空秋尽赤畀敌，为深难人想当甘。
# loss:1.163
# 脆浪清成只女婢，纸势清却霸转师。但赛枯草童人荒，海隅形花在枕亭。
# loss:1.127
# 聊桐龙口乘水里，蒙为椰绽玉精袍。依城载今余陆贾，丹衣绝露或有腥。
# loss:1.144
# 枕闲荒凉已感叹，谁前边根直天湖。也欲悬嗉暮沙鼗，官梦文茎话此方。
# loss:1.141
# 杯余轻恩云多豪，雕落妙国一三心。澄清竹烟迷雁谪，未从真骞牛泛河。
# loss:1.159
# 触人螺畴开烂操，送鲸群耳更色年。情余一人空气尽，山年终思晓云铺。
# loss:1.064
# 乘萧春首度擎芳，瘴山浅历客卢攀。鸿赛更斜炎芳出，海外涛春蝶回翔。
# loss:1.106
# 囊竹觉构物农化，珠然白蕉愧山。。自人新与寒地，，神长小花一发筵。
# loss:1.106
# 吕门高结接林垧，砌下编岭作短屏。菜甲初舒频染久，乱亭风生发鸡金。
# loss:1.083
# 协管灰旋入怜鸟，一分迎樯气复解。轻知浑觉归江梦，衣今远星一福难。
# loss:1.096
# 矾蛇吞象不里象，图余衔花为迟浆。奇堪白头偕樯鹤，爱留黄复不老仙。
# loss:1.102
# 溟和攘割挥牛刀，向我作别笑浮蛟。命兮雌兮人方左，云吰疑长共鸡头。
# loss:1.075
# 匾清走蒙岭沉骂，维方天更山相年。开是但我荒云暘，鹿出难踪耀多盟。
# loss:1.074
# 阃蝶未光九非客，日山是唐红作碑。口世几名何时法，一邑惆蜍死泽真。
# loss:1.063
# 漰蟹何当只呼照，枝术登途柳儿龙。怪石珊能淡黄暮，白山新是逐学城。
# loss:1.072
# 昏外烟插三天妇，灵何非灯照双台。胜霆里蝇无茶早，一夸相香想霜携。
# loss:1.112
# 舵臼轻绝悲沙头，炎宅新芽别小深。夕孙已去叫有赖，海说安酒说生狂。
# loss:1.117
# 释蝶灰旋万象新，东风吹彻联子蛮。满笼鹿书同五裕，披酒执箸初四流。
# loss:1.043
# 各波居逦逢远境，何原庄骚苦金从。海异得之秋在候，一风心雨把归秋。
# loss:1.089
# 翘裳声英自吴丛，朝登坚风旧子风。雷居香处清荡重，回山心轮蝶王醒。
# loss:1.071
# 善渺周遭红有向，凌名三洄咸水华。芳他晴联长多林，金鲸挥和回成留。
# loss:1.123
# 叨蛇吞象不须齩，三岁化骨何阴狡。尔蛇气道散求近，万鲸丛怅勒春寒。
# loss:1.091
# 公色形骸杯可渡，枝中深饮惊作湖。天家无人初无小，酒问黄此一雨来。
# loss:1.091
# 娟得下车政绩宣，甘棠载咏入诗篇。澄星生风能子草，白立又似逐牛河。
# loss:1.073
# 隐闻钱占争唤到，地波新心下发衔。残载万头无在凿，海风异尽尽为生。
# loss:1.061
# 祇花涯止同低沙，勋说一涛随牛亭。铃阁射瑚资护卫，披天应轮来用情。
# loss:1.089
# 音着单将乘莽葛，竞怀从轩更天足。三山同日曾云补，姿见应还来浮行。
# loss:1.091
# 属承鼻息扬箫音，筠亚齿隙调琴心。女儿别居椰水林，调画空年李海沉。
# loss:1.085
# 健雄把袖自歌呼，别样黄看三节珑。霜是恍春万水想，试问今时得若老。
# loss:1.033
# 幢桐有漫溯沙程，仙槎共标色色同。万槎平居籦须仙，披楚雌和终凡禽。
# loss:1.067
# 忱蝶吞醉清带光，博交凉着慎防亭。遥飘首照陶兰头，笑将相诗铁锄刊。
# loss:1.130
# 瑰晚灞歌飘杨得，红传扶着保笨天。色是霞吐千层卫，叶鸡遥风花二茫。
# loss:1.110
# 贞浪庶人翠画襦，陆困衔笼一厄罛。信是不名黄论蝶，十歌当年拙翠天。
# loss:1.040
# 幔闪中家六鼓鼙，将马民屿逐心频。盛年不帆清知虎，族汤寒忧蜡一孤。
# loss:1.067
# 括闪螺前开笑口，蠹中香岁已天。。阿班可微归雕饰，绝山城星流社香。
# loss:1.121
# 伯身剪彩鷁欲涂，一来似中飞嘘岁。道尽就随浑幽少，只见群鸥久定盟。
# loss:1.083
# 缠萧远难乡音熳，正腾此庐景色兴。晨曦潋滟恰随屿，花开如瓜初瓶员。
# loss:1.167
# 窝泉下涧三尺笙，千南雪属共北宫。今洲烟风无何有，炙背扶香傍短墙。
# loss:1.126
# 罅字题旋万是，，秋不头灯重难闲。巡画鹿兽千无国，一来难云过回。。
# loss:1.086
# 立帆三十六岛过，精灵呵护烦天公。荡缨纡事判沙线，鹿耳烟影添朦胧。
# loss:1.052
# 炬裳番踞碧内砧，踏鱼山五吐越莲。消啖应时频红洄，未鼓相携面半蒙。
# loss:1.125
# 卜社丁徭力幽纾，番娘饷税早捐除。宛池草冠金两少，只见方日一蒙堂双
# loss:1.115
# 呈璃风城八绝非，士歌利质旧云公。天说涛似喷百行，小来酣瓣天间时。
# loss:1.164
# 簿峰攒集黛螺黄，五蝶习林水家春。遥知圣主君烟金，海茫遥兴弱水芳。
# loss:1.108
# 宇得两人开陆芳，马然云五已锡春。解高丹悬舒垒鳄，阡田种心一明一。
# loss:1.072
# 潏蟹隐樯甘女东，四色沿中尘大稊。金知年去长王尾，广从北愧有鸡沽。
# loss:1.079
# 沉残罗逦列画屏，精载天中散锡红。一年不水何阴会，谦山疑问凤觳秋。
# loss:1.097
# 岛仙淡空物险艰，半仙宗寒天知闻。一极心飞籦半三，披闻银海作一流。
# loss:1.070
# 翛叶梅英并人妆，蹀躠无阴学中西。海载投酒来，民陌杂靖弓壤民。时是
# loss:1.112
# 余人水人渡万满，瘴望王里君学沉。白茫投丑护卢拙，轻头和露白战怜，
# loss:1.308
# 卸寂直踞千峰上，万里苍茫一色投。岁得倘子迷同意，界胜斑仁亦帆时。
# loss:1.293
# 祝着秋因嚼新沙，千看华子复语台。太名里民知多，，清长霜钟赤高云。
# loss:1.299
# 刀鹉螺物来告凶，鬼马沧却尚潮端。刺明西净疑弥远，包食各河共田家。
# loss:1.228
# 线果图日命画师，拈原晴将似无深。解知省输浮无翠，东日沥雁挛腰脐。
# loss:1.119
# 霏与何樯绕有垂，日客声溪驾人护。自岁里头成地音，为灵当华高影来。
# loss:1.172
# 骢门闲涎非林垧，砌来编护地猿敖。烟从乘政片生老，，漫堆桑耸穹窿。
# loss:1.101
# 熟闪攒结接林垧，砌下编楫作相迟。赤龙黄除将翔翱，旗常勋业符伊咎。
# loss:1.101
# 空油归卷成海万，一色成俗逃蒸熇。人若春之赤海明，未不微洲耳目凝。
# loss:1.112
# 卸寂山空八掌练，半上芭枰一知知。也蕉习同同生暮，试留黄然遍不胧。
# loss:1.073
# 戢蛇轻敲海九客，槟门飞更如夕晖。乱山断处好倾白，天声我静鹦宝歌。
# loss:1.149
# 祈字题玉荐女光，唱片新月草惊稊。开海想却来敷星，永皆常骑尽桓桓。
# loss:1.133
# 萝浪云成只女白，纸鸢画就走儿郎。梅通里波筑海已，好领蟾羽终归禽。
# loss:1.152
# 檐璃难重艳幽月，晓莫从醉万顷年。我丛城来两有水，缥来沧城天地焦。
# loss:1.106
# 汲舞题成教西谋，神头清味悦监春。弟知子来多雾力，姿鸠天花声两猜。
# loss:1.222
# 贱浪隐樯三在臼漫南灵盛月君天独。敢年南柑本光清，指是空花发落花。
# loss:1.175
# 惫泉余涧三尺波，南海新霞茄事支。千今不道调国里，到学晴火终赛腥。
# loss:1.233
# 版开良畴耕凿易，欣娘欲里殄鲲栽。片今乞岸征勤筑，潮信会今君水飞。
# loss:1.174
# 袍鹉螺物推丁渡，呼山此成知天清。忘机习静饶姑意，指者鲲身如数胡。
# loss:1.192
# 砚裳对踞似是纸，在光高里蓬外飞。道轩乞遭星臂思，阡学会俗问严身。
# loss:1.250
# 鞹蛇灰旋照西心，溪势王骨卜宦藏。分余贾功殊在惯，教缈浮望正疑门。
# loss:1.236
# 迎兢准汉渡渔岚，沧榼涡阁腥子喧。木思和诚淡后妆，未风应未一生亭。
# loss:1.278
# 丧管灰旋到城宽，石看三槎直渔羹。奚生风荡波里，，天天泼问来诃。。
# loss:1.321
# 睆管灰旋北女光，地男书更独标闺。轻开鼎沸历无福，要是诗教声目开。
# loss:1.238
# 代闪异口争鸣镝，并入偏鱼满传城。赤飞晴字诧田信，涸须民鸟重冷台。
# loss:1.170
# 尘光盆宕营余传，隐阑还原下赤铨。投花一粒清调竹，不冰嵌今消息花。
# loss:1.242
# 淤蟹何声只年谋，金摇登帆旧战吟。十发渐云迷红节，金问里低泼升无。
# loss:1.305
# 贴木红气似初师，雕蟾天手花人花。独不竹尔持雨热，要涛不绕天难长。
# loss:1.236
# 庸得下无庆南春，牙门理拍作欲痴。淅清老风恰地里，未月于觉细沙红。
# loss:1.306
# 降余狙底春投水，入中沧阳故海花。浩淼洪涛任歌脚，吕亢人共未青鹿。
# loss:1.391
# 该浪何当只地谋，难凭此味悦监州。双螯独抱炎定翠，吕亢图叶随中家。
# loss:1.268
# 灭残高域盈工阳，嶕鲸沉惯现诗衔。散山粗翁禾田腴，潮似文银共疑吟。
# loss:1.503
# 赭清走马到萧篱，江仔芒分茄茇支。小山内优解海补，扶涛难悔又战台。
# loss:1.509
# 稷和鞭峙人红伏，五鸣未马逐不人。胜论知南谁风称，携里一洲问边人。
# loss:1.637
# 丝本荡缨划莽溪，遗空龙花客当宜。有许纤埃侵舍出，笼心疑村小疑仙。
# loss:1.605
# 缳管灰旋入琳万，朱门抵拍谈嚣嚣。楼种问波趋清句，应官大渡不睆涛。
# loss:1.516
# 豹开童叟生冬传，的鱼王勒野渔衔。一山一魂波日动，瘴低佳携幛老长。
# loss:1.366
# 掇璃浓上锁孤佛，仰大从国市南深。好施消尽同禅寂，云觉琼花来蒙归。
# loss:1.394
# 稽人西锦枝头见，敲碎珊瑚雨作逢。飞阳斗童鹏无翠，六耳计今说清花。
# loss:1.376
# 帐粝儒餐看怀向，衣鸡轻晴忽不裟。初封张悬随黄蕊，回谷公山又阳红。
# loss:1.402
# 嵩璃叶西拖葸簩，破茸空林斗水门。地甘消下黄禅美，先爱青帘泛舫伤。
# loss:1.532
# 瓶璃对粤锁江枝，偶华胥花健于遨。雪明里民锦言妄，到光篱死种冷脐。
# loss:1.597
# 况意宜晴能月日，缕生富护不相花。雷今浑尾金良客，轻堂杂麈细原流。
# loss:1.333
# 威浪岛雄溯海钟，偏穰珠子咏鹊卷。好阳一年车前有，未典灯徧君午花。
# loss:1.211
# 革蛇吞象我酒色，归疏难莫旧沙已。九鹿明教不伏后，故山雪岸共嵌吟。
# loss:1.169
# 妉蛇吞象我琳璈，朱门抵掌谈嚣嚣。殊方问俗及豚羔，海隅鸿雁消客横。
# loss:1.142
# 矢粝儒餐初定痛，萧将旅鬓忽知风。轩阿知震云知长，一鼓扶蜍死微频。
# loss:1.039
# 鹆蟹旧樯成尺波，未上滋樯叱魔空。但酒但觉星辰近，放眼从知野鲲。。
# loss:1.033
# 旬浪神口首荒肩，一见仙惭舟楫才。东来在燠争吟立，相长三气月初终。
# loss:1.018
# 涓泉下涧三尺臼，女余神觉自云年。。是黄手将翔孤，凌女不边赛舞人。
# loss:1.015
# 桅许风灯远沙，，珠衔珠勒加鞍明。雪有一教本高集，载船铁骑几沧桑。
# loss:1.027
# 蹐易未卷逃星光，形光到意地染行。更是不层随里春，炙极无含数问仙。
# loss:0.948
# 桴蛇怪潮禄料贫，姿门初泼鑱华毫。澄亭衔处此时贼，插耳频莽羞无同。
# loss:0.965
# 灿钧淑屿露巉岩，蟹舍绝村为金年。尔鹿岂觉回钟后，噌吰应园下前员。
# loss:0.952
# 瞥璃案上金唤自，岁将玉着足似汤。年一斜日碧解籍，战今天情泛朦明。
# loss:0.973
# 宣今坏土都无恙，谁为守护劳山精。海封马鬣同生小，不月丛声玉莲青。
# loss:0.955
# 鲈绩渔光迥三之，陆困樊笼龙山英。情封涛晚北柈恨，一妍犹渡色际仙。
# loss:1.024
# 退浪庶竹都孙色，大携无月阴岸绝。年势未是埋忧头，争稀从知故壶风。
# loss:0.980
# 丑璃浓敲倾北砧，天步清春意知知。三山观马来敷治，故好当年一等铨。
# loss:0.971
# 神台若无倏若有，会须身壁黄台红。白施古划鸟风见，极鸡金风虚保山。
# loss:0.928
# 殷和鞭光日不亭，东施灰看天碧为。穷人仙人光无里，插是金献海之无。
# loss:0.991
# 虹开东辣饮露沙，雨华花惭惊天鸡。御班眩睫痿筋菊，出梦如皇蜡一丸。
# loss:0.993
# 畦落隐头海雨波，绝暖书遍耳欲中。海是霞子半官鏖，酒居仙携鸟虫平。
# loss:0.925
# 爨清走马绕萧不，指，何中方时势马稽。来身初低禅清宴，未必于公不老
# loss:0.941
# 阃君教象奏琳璈，扶楼沉风晚重宜。五不倘尔双双航，鹿耳短死联红评。
# loss:0.950
# 悠治群推可左路，鲲身文线多水花。书竹秋消异人赖，欲为杳子有海年。
# loss:0.951
# 玻臼浓露树孤海，水有无未展世衔。十载万军金清敌，开鼓遥声面渺美。
# loss:0.939
# 业门高结接林垧，砌缕东潮春年潮。自汤消似成冷鏖，踏鼓民比瑶时生。
# loss:0.962
# 巧裳风爱烂其喉，昂霄王阳两火霆。应嫩首除林多翠，凉听黄斗交气来。
# loss:0.930
# 迨清走马到鬼得，水岁绕月海中年。雷女香露轻麻茫，砰湃暴声重轻收。
# loss:0.937
# 鹞蟹何当北女婢，纸鸢从耳走诗频。花天朝种势二黑，千外瀛胜山。闲。
# loss:0.972
# 验月走马鲸霜柑，纔装官国一云鞭。萸酒已幅三醉彩，故好异啸重中。。
# loss:0.953
# 臾绝互涧三得蛟，攘臂黄翠旧防丝。一嫩粗丑无凝鏖，回天新须一城仙。
# loss:0.936
# 巧门高结接林垧，砌下编篱作短屏。菜甲初舒未是音，此教琼怅捕纷更。
# loss:0.972
# 亹蛇吞象画须城，东里化茫晚桅低。荒腾一时数处早，一拳起交秋用翳。
# loss:0.931
# 髯鹉螺前开笑口，珠光非更一外衔。伏落千头夜静鼓，畅好故。海任香。
# loss:1.006
# 驺蟹题樯忽女婢，纸山清西闻云溪。海载有象子前贫，物鸡一风年散扶。
# loss:0.956
# 黯蛇吞旋不冷隐，三岁绕骨苦与低。计中沧民清兴民，共驰寒马筹云来。
# loss:0.927
# 嵌人涯涘工岛念，华衮出怪气光诋。轻门难烦双三口，携留士与等膏荷。
# loss:1.023
# 春来二柳斗芳菲，散步清溪到翠微。怪石枯藤迷野径，残枝败叶拥禅扉。
# loss:0.941
# 笴璃案弹施远教，空枝于前竞眼天。到胜东非秋里仙。舆到破仆传良村，
# loss:0.972
# 房悬腻新点熳路，大谁身如也相宜。散天海色扶如里，一有安达不边仙。
# loss:1.016
# 揩管灰旋入四新，影，波开一复红。非谋几名八别见，白山雪晚笑蹄位。
# loss:0.951
# 住目北结木林垧，砌茸编篱尽相方。澄年载月行公，，一天成头潮瓶铃。
# loss:0.950
# 墨向喧无花音有，会山沧怪未山花。一知下云还子谪，天外无际寸高明。
# loss:0.948
# 楸浪隐樯天尺波，南来耆波渡更香。男声空须华方远，日吰应时蝶日翔。
# loss:0.974
# 骢叶春心游淼春，闲编急拍舵水穷。一明老树惟功笑，刺桐城村问玉喜。
# loss:1.006
# 牵闲风春度脚轴，羲望凌里胜宦场。垂橐新帆重野虎，一问安边陈息匏。
# loss:1.018
# 矑蝶吞马分入我，客歌高原下花残。有魂蕉尽诗天生，海海雪尽此用沽。
# loss:0.978
# 公田编享自小丛，我落坚阁一山边。情发今声垂蝴渡，士沙谁如留版台。
# loss:0.930
# 赬阴中涧三尺嵩，到乡钲拋尚济头。惆怅斗远时草鏖，四望盟戈尽故尝。
# loss:0.936
# 芽寂龙晖簇木镝，并门声与还喧凭。满到新巷双气水，为时安树闭中花。
# loss:0.963
# 已山红业山海日，破暖烟病色成寻。元知荒传来生音，华然海如共螭期。
# loss:0.932
# 高台极目海天宽，破暖金屿水虎莹。有余竹浪昙多小，一天时人减欲冰。
# loss:0.992
# 稻璃何竹逃其佛，将语已枰客印纹。木城不建瘴酋游，任廨粗营见疑居花
# loss:0.978
# 旁璃案上金千点，玳瑁筵满旧摧深。地腾绛联喷哥民，东南形胜孝再难。
# loss:1.027
# 壼泉是涧三尺波，女天天花已染香。弟知波德苏沉现，刺括恒河知林胡。
# loss:0.937
# 向台盆目海天回，瓮门连护散天中。南魂不得初民绿，我领未风三色地。
# loss:0.969
# 氏身准口量余扇，鬼儿珠声十火新。遥璞已行双色管，鲸空潮皇鼓无时。
# loss:1.004
# 旧他匹练黛偶凶，朝笼沧光旧赐楼。百年沧波双目宴，未领雌许待生唐。
# loss:0.950
# 灾重云山天海知，一风海青一深羊。离亭粗然人相晕，白山留尽羡诗明。
# loss:1.022
# 没浪异踞照北难，瑶田龙迎旧北衔。门家不月金王脚，听鸠风年共清来。
# loss:0.943
# 砖清走马陈鬼骂，祇光前界满书帏。男谋莫献原田膴，三浦官遣如节官。
# loss:0.985
# 援浪隐妨手峰谋，行步鹿到又宦车。遥红如道回首得，烂捧东声赛方蒙。
# loss:0.951
# 凿桐飞涎头巉象，偏思来袅上岸行。海势如年八何澜，英英不时动不口。
# loss:1.057
# 花信会妨三在臼，神光涌为一天三。海色风思黄伽歌，为问丛域不用更。
# loss:1.012
# 豁帆环车森林垧，砌成编篱作短屏。菜甲满舒频染绿，笋鞭未劚尚留青。
# loss:1.038
# 麾蛇吞象绕硜色，岛天闲竹受竹林。。竹十螺知千春，黄歌应迥那仰眉。
# loss:1.025
# 难留藤民一再见，阖门坚壁满昙逢。人取得荒初日重，波鲸心声面骑平。
# loss:1.006
# 雅冠攘割挥牛刀，向，载光似珊瑚。只舆十天何月老，万茫扶人历短墙。
# loss:0.988
# 隆门高结疏林垧，砌下编楫作相闻。百蕉情教茅阳脚，瘴得天人月金共。
# loss:1.002
# 深一奇宗不十孤，神潮古墓何峥支。敢余旧静珊音亮，止色一小重滔中。
# loss:1.014
# 嶢蝶山露如再妍，溪载王匀上渔褒。西事竹光多紫芳，檀移蹴斗不度秋。
# loss:1.056
# 峭蝶吞象清沙齩，奔交难林东夕浆。遥气小却来多候，海来真得瘴生深。
# loss:1.010
# 泽欲舂客溯散钟，淡食老五面社犀。书番指溅顶踵地，争来城节须疑时。
# loss:1.034
# 舳鳌捧檄渡孙鼛，舞乞骸骨万疑风。赤鲨芳帆金添果，鞭取冈垂成田难，
# loss:1.001
# 计网丁徭力渐纾，番娘饷税早捐除。只红十盏回醇醲，缦浮里自大鸡峰。
# loss:1.276
# 恶门高结接林垧，砌下编篱作短屏。菜甲初舒频染绿，笋鞭怪劚不官删。
# loss:1.425
# 谯蛇未草逃小累，天瑁初斗春嘘弛。他目一净无茶供，官好弼时月树见。
# loss:1.525
# 濴蟹下樯到在臼，南灵登培等廉公。夜秋朱到狂国云，天背得山汉堑城。
# loss:1.516
# 机榜牛畴耕凿易，欣眼三戏尤扶哗。海知西燠争倾果，月发风生大双青。
# loss:1.704
# 酌极隐隐匹有事，，水抵遍谈稀船。青洲荒功弱清宴，敢冉浮须添朦生。
# loss:1.534
# 安达波罗摘露沙，弄见一戏健涎牛。十载大里何日月，炙背遥过僧唐潮。
# loss:1.341
# 痕惊庶雾剧音名，红娘饷风早斗袍。一逢首金齐汉太，收好随身可故金。
# loss:1.370
# 会仙爽田同鲛肩，踏登鲸村逐沙牛。铃何一调月月叶，争发城望遍鼓鼙。
# loss:1.375
# 嘶月吐吞成水开，影鸡岂长海水开。味知浑播本再犯，好花金瓣戍茫闺。
# loss:1.255
# 飘明宠路耸生千，天灵风香立蛟重。剧雁城潏竞雨枝，鹿得鹊起行时方。
# loss:1.199
# 一缳作解咏采恨，今载民闻鬼欲悲。异域尽羞秋风老，黄花清忆故尽香。
# loss:1.344
# 疏林葳灯远埋舠，赤茸累气费晓层。酒眼变瑚空因秋，素珠蜈山兴九愁。
# loss:1.125
# 葵璃案帆秋八年，濆沦澎鬓腥入罗。满浪岐教人罕后，争从于石争故飞。
# loss:1.321
# 高菊何光故微辙，急须理事旧夕筵。白嫩吹除金雨管，东拳旧华浑海日。
# loss:1.345
# 咽他攒草非吴市，遮见醉迹乐短船。铃阁文荡林雅化，爱翠民身尽来人。
# loss:1.214
# 工萧左仗六丁斗，口光天市中花。。年露有鬼浮首运，爱发黄今破生流。
# loss:1.166
# 椽蝶波市碧痕隐，仙茫台听正游璃。荒服未将清地民，官廨粗营似荷星。
# loss:1.077
# 池义闽良踪已头，笥躠无荡一与城。番里二马甘白空，月南南人为明虎。
# loss:1.123
# 索箐儒餐初定痛，萧疏旅鬓忽知风。万妆但引片垂尽，高见舌晚倚槛听。
# loss:1.107
# 谟蟹下涧争海好，扶摇王里旧战新。男和黄梅云饶水，秫田蟾蜍四火成。
# loss:1.049
# 帙管灰旋万象新，踏月惜月地峥地。敢清难辔可道渡，三施稳香鼓子筹。
# loss:1.006
# 巾管灰旋奏雕鸟，纸鸢鸟觉波碧旋。独随深门声有法，柳世黄鸢话三发。
# loss:0.985
# 港开新神驾露沉，分罗山说波日时。窗是指佞星论定，放方铁父尽桓桓。
# loss:0.979
# 刚身准气倏自醉，功门长东满印新。大片投药北朱际，未到冰处过。屏。
# loss:0.924
# 箬泉下涧三尺渔，南海新涉王沉稀。那红海日白如口，天云真落雨凫鷖。
# loss:0.905
# 畦管题蒙布女光，老里小复碧天滨火醉月生愁清榼舞，一今一园淑气城。
# loss:0.934
# 得迷回容陈茂骂，奔腾难着谢南林。桐日榕佞三似供，拓长出声无万行。
# loss:0.902
# 伺蛇吞象不须齩，三云鱼彻使阁低。荒服尽余身公地，齐天低见狂青家。
# loss:0.930
# 螭泉是涧三尺波，女儿没护鲎独香。勋域一来能散物，白把龙林贤西花。
# loss:0.912
# 躠管灰旋天萧水，指来无开健不。。雄岁照放苦野意，翠携游虱真当车。
# loss:0.850
# 创佛浓蕉簇孤力，荒沐仙马焚兰师。酋风骀荡天风世，族雄子子日有夜。
# loss:0.850
# 恙月走吞成四照，江穰南云年沉心。遥山不际归香里，欲来香忆未出香。
# loss:0.903
# 杏佛盖外窗镇地，也首匡庐健涎平。也眼里风堪处水，谓云玉供冠远时。
# loss:0.911
# 翔留教学低星宿，厚爱皇色玉雷心。白是蛎里破把臂，相看先问近者城。
# loss:0.901
# 邹管灰旋照颜日，高，到隐岁成是大重。台茫海南无他眠，白围丛时鸟舍
# loss:0.927
# 狗渺轻便龙远耳，志舍仙此红笔晖。应堪应山输齿翦，马到闲洲取钧潮。
# loss:0.880
# 虚榜喧传姓氏先，文章台阁吐青心。也知但佞天终菊，澹年天已一花。为
# loss:0.887
# 辟箐儒餐初定痛，萧疏旅鬓忽知中。为家眼静行铃小，出来知忆未知山。
# loss:0.865
# 红觉方漫接唤镝，并入坚潮多水工。一令巴似昙金挑，五把冈讶小赛秋。
# loss:0.937
# 涂水烟极六花恙，缕崖倒拍海潮回。雷声鼎离浮田犯，回施消息问严公。
# loss:0.890
# 辔身准檄竖横沙，的砾中序届人风。不今乘风君前里，极胜族梅四蚌风。
# loss:0.862
# 笳嫌驯良首打猫，我北三味纵喧辰。此海应燠易回地，酒心于难龙云去。
# loss:0.844
# 挂惊驯志余打涂，楼女不马向成眠。三明声声一日早，不邦桄渡不纤更。
# loss:0.808
# 轴璃案上金千回，地缕华唐一如十人天。家是无人无余泣，当传死物人四
# loss:0.865
# 温蝶吞残酒非知，。交官醉出战罗。醉篷指洲长百里，归茫一槎试问涂。
# loss:0.865
# 廋蛮下市女芳菲，望中先贾若九持。分关如群三林楣，万家遥风一共愁。
# loss:0.799
# 饥蝶花空清中照，蛋月光原惊蛟好。十山骀集清气少，族载骢什扬千殊。
# loss:0.871
# 百瓮余软原花开，维崖倒拍日潮回。雷里鼎沌天贴贼，插窜变口书浆城。
# loss:0.855
# 车残虫鱼增注路，，门狂子山迟收。赤衣旧槎秋钟实，入括普湖重由亦。
# loss:0.900
# 懒臼案粤金无光，宴圃犹林水天嵫。解日纸尾林无补，信龙林如天呼。。
# loss:0.828
# 佚燕题玉荐女光，治望九罗鲸天祟。事日使佞倾西蝶，绣瀛仙水重渔更。
# loss:0.861
# 善钧周遭蹄其涂，一山台现万日碧。乘得不幅投语小，耸外风上一瓶删。
# loss:0.847
# 毂裳直踞千峰上，万里苍茫一涛城。不里如诉初苍远，痴唤兰识资公儿。
# loss:0.847
# 国屿丹齑禄料贫，朝阶一光说笔端。吟阳生腔鲲蝴鸟，误山真恩玉铁公。
# loss:0.828
# 髻和攘如似长元，蛋船傍樯上珠公。狞令几畜海双亭，波雄一时初在沉。
# loss:0.817
# 名油帐底醉醄醄，仰天狂叫首频搔。男儿莫仅鸡垒化，碧教鲲戈雨蛇成。
# loss:0.882
# 夕茶仙构认农家，竹雨无帆美人妆。命名当似渔天市，一秋沧波接华沉。
# loss:0.911
# 以帆三集不初破，花妨黄耳来边年。真女香浪浮为动，绝鲸相人海小新。
# loss:0.828
# 变岚衔后清渐尽，古中庄前试西宜。极目发采远无动，叶闻蔗雨花灾早。
# loss:0.907
# 统门高结接林垧，望下编篱作短屏。菜甲初舒频染绿，笋鞭未劚尚留青。
# loss:0.900
# 利他匹儿亭拍肩，踏来意气年天地。忘机习处又此城，着更潋柑遗上，，
# loss:0.918
# 养明西命有十下，如范跋复遍社公。佛龙惯语筑变渡，盈椠风飞重天。真
# loss:0.890
# 嗉蛇灰旋万象新，东风吹彻一山开。不明省识唐虞云，阡陌萍风一无翠。
# loss:0.874
# 袪蛇轻车不离客，玉望三风如鲲衣。更人甘雁渡则已，归谷烟作不蛟东。
# loss:0.904
# 铺裳直踞人峰上，万传成里两子门。三许纤竹侵衰青，蚌芽云上最高峰。
# loss:0.921
# 息屿鼻息蹄箫化，筠亚欢勒市赐寒。初蚩不鹿静无妻，海深形丑无生有。
# loss:0.950
# 桓鸡攘割挥余宿萤，衣仙更气见云深。忘机习静饶光意，也叶春年拥翠远
# loss:0.936
# 蜈泉残当留芳谋，望清樵见客迟浆。应城似花势波堕，鸣落发此天清功。
# loss:0.921
# 缆字灰旋忽象婢，清千是气海人支。两字是群浑飞女，未枝花天兴大天。
# loss:0.958
# 罛泉残碧暗蜜谋，纸见寒别闻城花。地知不蝇无余泣，当家风日一阴铨。
# loss:0.960
# 超沉准民量清英，枝枝此岸赤心西。天里秋生初额已，高钥一调画舫心。
# loss:0.885
# 敷茶甘蔗逢佳境，中世芭花尽语花。也归万涛频变厚，万将挥作龙回翔。
# loss:0.900
# 头觉极凉已感叹，更来草历见雪围。千米古头筑里来，谓耳连家细旌听。
# loss:0.919
# 妍施鸟喙又中申，远困气飞大喧红。嗟时海浪都最脚，广及首笑一未台。
# loss:1.001
# 连是喧传姓氏先，文章台阁吐青腾。轻年天集清避幻，好声潮生无淋铃。
# loss:1.020
# 喧茶良蔗环千天，，金天从南地南。。更路声华波来不，欲花难茎洒头红
# loss:1.000
# 峭蝶吞象不须齩，奔门坚香不诗忙。木对倏处成腥饰，踏南深迥开浪香。
# loss:1.042
# 写消庶武踪露里，祇指空分向水英。绣机天筒来家仙，小往寒烟成有国。
# loss:1.166
# 贯渺周餐云设西，一落路原拥。春。命鹏不鸟投幽会，归鸡放赦细号联。
# loss:1.049
# 笈清走马诛多点，治到船营海上涛。好知沧波双病好，酒声在风似藓金。
# loss:1.253
# 再开虫口可注脚，志眼飞村山二耶。由家一前锦寒脚，，更衔北俸出净青
# loss:1.257
# 势却远法教三沙，淡转罗知旧毋新。穷途苏尾诧门醪，归鼓遥声数气公。
# loss:1.289
# 田着其沙蹄其城，竞眼台醉吐虎心。龙阁棹饮同不恨，兹游真羞旧和行。
# loss:1.487
# 罩与灰旋万隐我，影飞清触霸猿舆。十是甘士横洋险，腾眼清年留树肩。
# loss:1.354
# 亮臼出学易牙鬼，软上光市焚喧嚣。满家渐音渔淡春，险，相声如雨春嘘
# loss:1.309
# 紽与飞蒙照蜜光，腾色南译天茇书。丹山内洋近自贫，四鲸一携赛藩篱。
# loss:1.427
# 耰与重岛争峰色，踏头难醉谢入槽。自头气年垂翅避，华绕风驰都竹凝。
# loss:1.069
# 嬉字题玉试霜柑，纔桑偏里日年集。绣息何使歌乐利，我欲舌石共官花。
# loss:1.062
# 勃泉下涧铁儿空生客到天。独岁里年留海浪，腾食只父碧为舞。初长沧风
# loss:1.087
# 宋消驯缨堪难粟，志眼江气隐无宜。尖许日波初柏尾，爱领未射下气篱。
# loss:1.089
# 紫渺寒姿菊牛照，士中如方新为空。入春不斜三来在，海邦秋兴一知音。
# loss:1.153
# 灌闪螺前香酒漫，蠹烟利诗试鲲雄。白城一道曾雅化，爱欲童子抱蹄蜂。
# loss:1.089
# 铸节准口量余粟，一榼花瓢破气碑。瑚网蹴斗将荒中，赖天心前为丝家。
# loss:1.250
# 棨字题成教女婢，纸鸢画影走儿郎。两啖骇民雄同考，蛮好异翠来中山。
# loss:1.231
# 佛草贔屭度叶阳，匹马罗胎更群哉。遥青盛向枪柈清，拾学耕心如雨云。
# loss:1.288
# 凶峰贔屭拄南阳，瘴仙文楫清离褒。假若冥云两尧东。回岁一蜜暮林中，
# loss:1.308
# 蚕蛇未光清非着，不云富翠腥英攀。嗟事仙帆天金近，天用城山图本殊。
# loss:1.207
# 捐蜜鼻息扬箫音，筠亚齿隙调岁鞯。朝阁明来天相夏，至雄只河云狂左。
# loss:1.164
# 骂蝶花残清入梦，大来成花拥落春。我浇神知成能线，即耳浮影得老。，
# loss:1.035
# 歧载吞卷扬增知，一欢篱醉一防狡。尔明一有迷醉湿，舞雄里犹着爪伤。
# loss:1.061
# 熊蛇吞象处须齩，东岁化骨何知通。好向风似洵春口，神更弼斜吐可沉。
# loss:1.148
# 绯泉下涧龙海四，想摇不碍万盈鹅。动官神炎凭齿头，星月瀛涛未生饱。
# loss:1.157
# 挥垄十幅驾生槎，陆霄凌胎子厄城。我是笑悬及翔中，光云春人赴前澄更
# loss:1.262
# 冉冠闽相又林元，施食罗南来知年。穷园仙来无散月，万人遥今无来涝。
# loss:1.672
# 调茫岛姿挥清蝶，林年绛他未古通。道蚩恍前红云年，闻里得过何笼鼍。
# loss:1.960
# 橛难云气到阴漫，却河羞涩等声湍。举地斗觉千再后，争今金洲冠林生。
# loss:1.683
# 鲲施渔鱼还有钟，施门初国满沧宜。澄望已郁原多在，破发沉前细清枝。
# loss:1.591
# 弼蛇灰旋忽四水，影指日风扬千忙。天到吹却半黄铃，死捧民影冷不闲。
# loss:1.266
# 夷水坏土都门气，蒙国沉笠也精袍。狞书骇兽乘卢东，故外久蕉暮欲同。
# loss:1.129
# 谭闪匹结接斜名，每有捷瑚高作逢。好。海道遍幽来，踏草清溟睍驰鹅。
# loss:1.196
# 蚀字题社万来年，高瓣身里旧天逢。有说烟年连何妇，神年纔茇日枯焦。
# loss:1.096
# 蝎泉下涧任海满，难君由更不群栽。两乳纵投何空动，一极扶云徒玉花。
# loss:0.977
# 磷字题成教女婢，纸鸢燕恩海如年。金不年闻天方笋，至驰黄影驻鲲屿。
# loss:0.966
# 肥从准难谪氏涂，文章此阁朝水真。散绮应午频染绿，拍。莲皆击壤民。
# loss:0.925
# 瑶萧春解为澄，，醉衔黄看共相妍。应暴斗兽北谁云，殊鼓相香如独桃。
# loss:0.907
# 缬清走吞来萧发，女骨官同磨诗旋。三载簿书劳梦寐，搴帘卧理愧前贤。
# loss:0.874
# 裂冠闽邦控入头，昂到瀛历满天子。窗清日愁本颗妇，鸣险黄与小姑心。
# loss:0.839
# 獮叶出马不知贫，三枝难方见与远。分开尽有成无里，更生洛下山际归。
# loss:0.834
# 殛泉下樯三尺波，南天于波别莲收。动红里音都畀敌，由月何教口散莲。
# loss:0.876
# 和马单衫挥羽扇，炎方空说授衣辰。雪魄冰姿淡淡妆，送鸟微有开城地。
# loss:0.865
# 颂渺理便入其近，送庸同国最深春。大天不女耀田不，调花无时天隐新。
# loss:0.792
# 契冠腻割惊露心，悬下醉掌毗扶哉。可居族道同生新，海不形时五为天。
# loss:0.815
# 汗身准彩浓何水，散茸空溟作波情。伏到日幅争卷来，蒙浮无来为独尾。
# loss:0.809
# 妾蝶吞象与我津，空里一发乘为碑。东外应树雨风云，浮是杳然暮劳风。
# loss:0.815
# 尤裳直踞千峰上，万湾盛贾见盈东。不里应逢孝归萄。山有秋音愁语中月
# loss:0.859
# 章旄高插远晴路，风繁台看似火台。保萼临风来三法，姿消烟然路调名。
# loss:0.831
# 樵影觉梯认同，，风林篱山为名鲜。不山秋音金光度，信他何测海独胎。
# loss:0.853
# 叫今路解人边履，惹盈古山殄是花。轩淼不愁清枯，，海空城园贡华台。
# loss:0.826
# 箐清走马到萧篱，芒仔芒分茄茇支。换月内优解鹿脯，稻香蔗蜜厌唐师。
# loss:0.809
# 皴门高结接林垧，砌下编篱作短屏。菜甲初舒频染绿，笋鞭未劚尚留青。
# loss:0.837
# 息人淡餐鲲冈边，瓞衍芋匏韭本丰。十风蒲仑白水想，金来浮有山时霜。
# loss:0.848
# 徉蟹下樯铁女婢，纸海闲气地回。。好山风无落，世，烟天新重尽。不不
# loss:0.807
# 袒浪何樯椎尺佛，芒海芒分认如开。天尽得年无前句，银潮沧尺知象更。
# loss:0.800
# 矶开觉路难蛇去，入文台里万印衣。更望有兴调最脚，晚番挥问待息河。
# loss:0.802
# 萦却破缨分氏涂，筠笼熏惯不社伺。到春潮燠野时发，拓将风群洵大仙。
# loss:0.815
# 滚兢庶十似若香，相湾行阳十日年。乘知背别又泽长，高是云人夜烝小。
# loss:0.803
# 豆旧别山八匹照，使水一壶楼丝犀。怪石枯藤迷野径，海腾初山消者归。
# loss:0.798
# 园挤不去已三年，千首扶光更气非。古笑一似成奴俗，淹围同笑靖归笼。
# loss:0.832
# 报钧无因嚼去程，马光风中树兰春。更海新前天阴赠，水香风阴洵布深。
# loss:0.803
# 床箐农餐初千肩，初笑如马驭驯良。相露小圃曾雅鹤，山遣风花浮轮行。
# loss:0.827
# 铺裳直破碧家无，，落扶篱更山人年。。雨山一须波深，，天海天小一空
# loss:0.840
# 新社溪街成六山，相将东靡一波新。遥知门屿漫为度，色枝形人瘴无深。
# loss:0.843
# 缓怪剪彩云周笋，翠衫轻相旧南新。初竹气名垂醉客，未冠丛居试问涂。
# loss:0.800
# 盖岚别风非成熙，东然篱轩欲中花。过方古蝇图长见，万茫幽人传摇花。
# loss:0.773
# 鲁开坏土都无恙，谁为守护劳故精。。年易如今逢圣，，神看如孤不。虎
# loss:0.790
# 狃泉下涧三尺波，女儿没水如群鹅。中官投药山之阿，至今门气留瑶谷。
# loss:0.831
# 登好若光集目沙，花海巢气焉虎久。春头如天到华有，误香清线存目明。
# loss:0.831
# 仍嫌繁错划贪饕，追欢新卜焚兰膏。阄题射覆月战鏖，齐楚盟会联滕曹。
# loss:0.821
# 然堂盖瓦窗明纸，一下无惭不用无。迤涎浡潏竞公台，未陂不生无阴亭，
# loss:0.833
# 如君小孤化增长，下里新涯焉大声。漫字无过长济海，八归执水千无家。
# loss:0.811
# 珓泉题涧三雨臼，攘潮安绩欲日闻。怒是孤觉倾峰东，蛮乡应洲晓台来。
# loss:0.799
# 桓身准错量教粟，一榼无瓢万车烟。今海蒲塞烽田后，也夸北采向公蒙。
# loss:0.773
# 汇得朝车能病近，隐欢珊更是更鞭。。春槎水能画里，小梦不遣暮问洋。
# loss:0.758
# 坑蛇吞象不须齩，三岁花靡沸东。雷岁仙意光由国，即雄应烟野有深。天
# loss:0.726
# 尼得山车结绸缪，雨到成似一蛟成。岁里暮姿见洲信，金方怪石争钟人。
# loss:0.787
# 城八余空绕非妍，秋然花地语知胜。乘兮就科从清动，极者已携火问蒙。
# loss:0.780
# 棋得下车政绩宣，甘棠载咏入诗篇。星星亭落清呼后，万古如上存白明。
# loss:0.803
# 慰金飞列看红水，千湾中卜绝幔鱼。不味一归奚在口，任桐蠡影夜难犀。
# loss:0.834
# 土垣编味都其久，教衔如林健粉溟。一城王随秋鬼民，故遣翠怅捕酸儿。
# loss:0.836
# 尝冠腻新闻音妍，醉题跳舞惊鸿翩。酋长朝来易版籍，东家麻达西家横。
# loss:0.836
# 非黎乐享承平久，士然一戏闻深红。忘飞不睫痿筋小，不到如华送日同。
# loss:0.884
# 毗得下车政绩宣，甘棠载咏入诗篇。澄清揽辔知公志，愿更弼时重仔肩。
# loss:0.793
# 叮佛高难簇一枝，偶为五歌日人迟。四山西兴斜野径，新邦民怅捕园芳。
# loss:0.728
# 扁字题成教女婢，纸鸢画就走儿郎。此翁得丧无九接，相锁如钟深在仙。
# loss:0.766
# 映榜喧屿姓边号，瘴潮此蕉避心嗤。微瓣古寺天由长，雄开千觉关桑红。
# loss:0.853
# 海壖残腊试绩半，光得吹彻满作中。悬海洪开金江头，来时诗华一层叶。
# loss:0.939
# 内萧良脆秋处界，，转呵护凤虎天。轻蛇清书掉两头，更天新叶雨蛟骚。
# loss:0.905
# 合霭添浪终其伏，沐山瀛气试浮台。天五纤埃侵皓素，檀心秋语共花洋情
# loss:0.882
# 再幅征缨自中沙，生山光气焉翠九。十载北路鸟皓素，未方瀛语成未更。
# loss:0.832
# 环台盆宕不小见，望沙罗屿鲸夕凭。任和一居清须后，雄常常羽四池歌。
# loss:0.826
# 描他攒练非吴名，偶山灵子故万年。轩人帆意知时天，插云鬼涛又同桑。
# loss:0.812
# 奔香筛蕤羽长沙，门外成燕衣赤新。洛书里来万由早，相有天生一百台。
# loss:0.850
# 駹鼓波下拖玉练，更阑一肃王色凝。阿班眩睫痿筋力，出海环珓频难稽。
# loss:0.851
# 姚佛山前八掌练，更阑黄标烟作香。口高难沸黄空翱，旗漫勋业星走听。
# loss:0.871
# 掩鸡攘割挥牛刀，向我作别笑浮妆。海载岐人多黄知，万浇无风图子昏。
# loss:0.784
# 猷门天十度有天，叶翻平堆草春红。散重泉向连时中，清谷拣香万昔贤。
# loss:0.772
# 礼余烟近三动水，极人沙向地曈曨。漆来晴主已时令，日海光解共日明。
# loss:0.811
# 鳞闪高结接林鬼，枝枝一娥笑深妆。远名不日逢自澄，天不起波仰息车。
# loss:0.777
# 择儿互涧三与波，女儿没水如群鹅。清官投药真定出，腾是风水重月。，
# loss:0.773
# 鸜泉下涧三萧波，雾到春水闻书犀。弟吴有里无气微，一茫稳竹勒客新。
# loss:0.781
# 巨残宠光羽盈盈，神文同卜共作篇。殊雾倏群泼田利，甘戟连马碧老因。
# loss:0.795
# 呶得下车政绩宣，甘棠载咏入诗篇。双清揽辔知人重，漫岭烟螺是一春。
# loss:0.773
# 葩璃案上金中点，玳瑁筵前林名亭。试春二梅华紫俗，赤船民如似重花。
# loss:0.784
# 亲治波罗摘露满，倾潮狂高地深工。口随不烟留能翦，耆沙槟榔劝客尝。
# loss:0.832
# 热身准彩余何立，深枝篱前月相天。。春老此知扶地女，山难幅俸在中。
# loss:0.808
# 蛤泉清涧三尺波，匹天天水山色家。但是浮波清榼发，不来如天乐日云。
# loss:0.790
# 评蝶云残分山垂，五官东鬼霸人留。夜外泉有成沉功，即衣一影添朦。。
# loss:0.844
# 惫泉下涧三尺波，女儿没屿暮日祟。海仑变牛禾臂鳄，笋风争节幽作稀。
# loss:0.818
# 颜从舂床散何迦，一来花原鱼喧横。拜罢耆童珊瑚传，凉指同吼度春明。
# loss:0.756
# 叨蛇吞象暗须津，马酒仙市一花民。有轩幽知成时补，不开沧瘴一社闲。
# loss:0.786
# 寿霭渐蒸走千韬，燕霄蝶气君毋挠。更途晴晚行云令，千到霜园雨蛟沽。
# loss:0.801
# 告悬征气刺画海，乘出沙又忽赐非。他山棠命见静卫，金乡蔗蜜未蛇龙。
# loss:0.864
# 韬浪多露露家禁，前分盛轩几知花。南知使节来敷令，万人海里扶日女。
# loss:0.961
# 存许剪传控铁照，瀛中合配月玲珑。不春不散有地少，山得起问问腰横。
# loss:0.939
# 药泉何涧艳海一岛低满岛沙马旧已持。竹与卧波浪银矿，开片萍觉面春兴
# loss:0.966
# 莲身风床侍释迦，一里烟叶笑于牛。阿暴应射频似径，式时败界一瓶烟。
# loss:1.094
# 仄字题成手画一，治空不妇散双昂。分绩尽饮黄黄发，日外新是随落帆。
# loss:0.973
# 报承单喙似已襦，陆困樊笼水厄罛。信他官觉浪鲸蜂，高来登帆柁如深。
# loss:1.030
# 空生更北愁经霜，东在民散鬼民老。胜阳日年常醉奇，栽船雌气尽蹄。。
# loss:1.084
# 蒋管题成霜在水，柳落何潮水二城。可浇变回自晕恨，万汁不是尽心。古
# loss:1.116
# 拊味隐樯天在臼，为邦出香叱沙听。千樯篱屿交黄食，万谷佳人争摇船。
# loss:1.160
# 盐寂对踞千峰重，在里苍也忽摧逢。非余岁影清寒供，一汁光是两金鸣。
# loss:1.077
# 檨蛇吞象不须齩，，帆抵国看于浆。女仙断头走鹿颊，岛酒王交未时生。
# loss:1.105
# 犁竹觉构认首萤，万拥如骢一地情。气外西南白风有，瘴典澎樯一夕儿。
# loss:1.108
# 槊泉下涧三尺月东妇不是岁依持。红洲铁瑚熬须卫，日人败时初禅远。相
# loss:0.945
# 渚君得有里三漫，蛋来妇子海花山。萸声观余鸡远尽，一家篱落暮烟枝。
# loss:1.005
# 庸得下车政绩宣，甘棠载咏入诗篇。澄清揽辔知公志，愿板雨白为瀛官。
# loss:0.949
# 肖蛇吞象不非齩，东岁滋骨慎防心。舆谋一去遗芳草，宫见雪度洒芳葩。
# loss:0.913
# 牧鱼轻月清非海，三家花共直东西。也知不客浮把地，为声中今一未清。
# loss:0.940
# 骓得下车政绩宣，甘棠载咏入诗篇罗澄清揽绝远归因，赤龙登旭日不焦。
# loss:1.028
# 矜钧寒姿菊心英，燕羽仙水一用瑚。相山不道何春妇，更海安壳为边冰。
# loss:1.055
# 头向何乡低脚士，马听珠身更图茅。楼笑长联罗汉绿，潮将卧骞消息渺。
# loss:1.086
# 莅泉残涧三尺波，黄眼清水一九收。采拜是教劳兰沉，前似青。师为英海
# loss:1.103
# 掉榜残路渡鼓盈，螺黛狂气费西来。。雨日年恰海升，无无好是无把金。
# loss:1.116
# 蛎清出马到萧篱，芒仔芒分茄茇支。换班可前辞无新，卧花难幅冠红听。
# loss:1.367
# 柴和鞭光碧已茫，盖蟾泻村客喧非。青今烟愁凭清日，归掬微作龙泛中。
# loss:1.244
# 忧竹盘漫悲变茝，大湾无叶尤语门。离亭握树投钓渡，戈涛烟翁泛高笑。
# loss:1.301
# 蕖棹共樯卷在隐，蜃门编约如字褒。万樽日风车涛洄，也来应洲却目方。
# loss:1.251
# 粉鸡攘割横牛刀，估分绛之达竹林。路书应同奚中里，炙无当雨把锄舂。
# loss:1.219
# 论粝儒餐初定痛，萧疏旅鬓忽知非。百片时幅回更里，绝觞耕类那炎时。
# loss:1.219
# 尊头觉路花生履，振落罗软天无春。不是滋人多五彩，白省草微侵阴听。
# loss:1.132
# 沧传瓯塘千八重，濆沦澎濞不玲人。雷人一有共成升，春外满余秋雨仙。
# loss:1.258
# 俳蟹余涧变南谋，客步清溪见翠车。千乘影日托瘴奇，一前脱啸鸟水天。
# loss:1.307
# 锁身剪列三东路，岛屿晴铁一如难。更行遍是狂官出，鹿来浮幅残紫阴。
# loss:1.458
# 蚝浪隐樯照隐一，叶点声生冷子悲。是载落南安到句，谁情炎曲笑蹄涔。
# loss:1.346
# 淳闪异结齐鲛室，踏仙芭气碧忉天。遥华老草国两口，椒春深俗不多仙。
# loss:1.256
# 缠惊贔屭拄坤轴，羲毂轩轩惊相终。初飞年限谈临妄，称酒文星解一飞。
# loss:1.167
# 穆泉下玉三，光枝金翠到分丝。应今一语路奴满，潮发英达一此秋。也名
# loss:1.081
# 完身神海三生天，大门斗向疑玲红。古飘贾识倾功盟，式来涛是狂马潮。
# loss:1.386
# 娥蛇吞象不须篱，飞声飞到疑初赊。。春天子须三小，携闲含绝亦数焦。
# loss:1.325
# 剪香烟向乡羽来，为风无原人名万。离前临浪看光贫，扶桑常仁播远桓。
# loss:1.451
# 骧管题旋万四在，影锁三帆健子闲。王当倘柑持无热，东南花山慎禅虎。
# loss:1.730
# 恍影初衫初何迦，一槎岂鬓早南时。味随突向水此音，拓夸旧却十际深。
# loss:1.538
# 培浪繁罗谪入城，官身惜线暮头家。真雪贾齿蜃无翱。夜深无俗原淫惂。
# loss:1.187
# 压他攒集黛螺青，无天珊落见摧残。如是尽边渡得流，殊腾犹理臻一更。
# loss:1.034
# 高知暖风炎倾渡，神仙利仆地精褒。年宇久喜镇生翠，三里风秤似梦唐。
# loss:0.922
# 梨旧螺畴耕凿鼛，偶携无笠一美奔。更落安耳秋敷治，华常深皇蜡溪先。
# loss:1.024
# 紫葛周遭又其口，口砾小灯灿落霞。海生斜麻有。飞出西俗问浮中。人风
# loss:0.830
# 净明声结接余客，不妨珊世欲天潮。非女涛影黄客树，鬼鼓香螺织静鱼。
# loss:0.859
# 透璃山卷天意险，朝暖烟光映笔端。吟到日斜何兴星，天用一山十昔笼。
# loss:0.819
# 峨蒙庶儿每拍肩，踏到谁气试回看。乘雨发谱循良传，喜信微情取次刊。
# loss:0.805
# 椰帆象意炎晚枝，我袖竹燕暮不城志九。一说从如草前期，远缈非月头瑶
# loss:0.859
# 拓门山马复岛久，秋来新燕一为鱼。花到一道一是先，却花风水归春阴。
# loss:0.798
# 婢得波车政绩宣，甘棠载咏入诗篇。澄清揽辔知公志，愿更弼时重仔肩。
# loss:0.760
# 坚明高十乡何见，海潮深分受浮静。有是老集有里，，雄驰骢什抱遭名。
# loss:0.759
# 贞冠攘新相斗妍，神头灰画鼓西鞯。雷霆一震黄麻宣，包来鼓块开枯。敢
# loss:0.800
# 含挤不去已三年，千首诗拋出牛耆。铃朝影文埋清宴，故世心年一等罗。
# loss:0.765
# 湘却路底世渔称，绛鱼山咏号无真。百绮海似公无春，界画飞作话地碧。
# loss:0.765
# 鹦鹉螺集同鸣音，，下醉斗毗人红。残山泉到鸣番白，天狂风下应气生。
# loss:0.698
# 蹐得下车政绩宣，甘棠载咏君诗篇。澄清揽辔知公志，愿桑谁此冷冯云。
# loss:0.743
# 恺得下蛇沙载万，晓花天别有上新。清今朝向秋人老，黄花空忆故园香。
# loss:0.762
# 任岚高屿三初清，秫云正篱故中意。舆中宦沌海狂晴，却常挥香山独花。
# loss:0.744
# 诳管灰旋万象新，大儿影阁万水难。好年偏向天多暖，小汤一归惟遭空。
# loss:0.782
# 锄身剪涎走难里，管看开客火不深。好东二得多海在，拾天杳翠渔归高。
# loss:0.734
# 崚泉残涧三，谋，细榔谁家成。吟出一震云未重，清落丛竹勒落林。一门
# loss:0.755
# 关望春空海水，，一春深沸散田城。海条秋两罗伽小，一海应轮认梦员。
# loss:0.758
# 始箐清议自难逃，潮衮无气碧云肩。标暴应悔留雕翦，天风南叶消人金。
# loss:0.722
# 嫣洪灰旋万象新，东风吹彻就作频。莫马照童尽似意，小是春人共茫舂。
# loss:0.805
# 掏东自邑谪腊指，碧茫影看赴重来。不里鬼风射馆浮，白蛇会洲水头仙。
# loss:0.741
# 泓泉十涧三尺稻，高意天分已云。。缨里不垂岛天，小乡中分为来有。会
# loss:0.724
# 襦门荒凉已感叹，更听黄原足瑚罗。铃风夜月非金会，莲仙湖生似紫来。
# loss:0.774
# 伸泉下涧三尺波，女头衔水浪清山。。垂岁照肉白凝方，故年新荡寒火有
# loss:0.758
# 致寂余虚簇孤近，天海无事两道东。木南金建耳同小，一瓣遥日在鹿鹿。
# loss:0.760
# 街璃山如北鲸乱，雕龙万语万锡工。散蕉巴有初时妇，酒酒如今一壶堂。
# loss:0.790
# 硬泉下涧三，饥教五月为影重。遥今海人夜把臂，船将一语添朦胧。微天
# loss:0.713
# 乞开觉路香生履，振落天花色染衣。更上一层回首处，故山遥望寸心违。
# loss:0.708
# 早阙宿娃竖横沙，的砾此袅洋兰衣。惆长寒建烦桑小，椒得安色为人羊。
# loss:0.763
# 鎗蛇山残九入知，南湾中叶岁无天。海尼无数惟功狗，贸易异头来中仙。
# loss:0.715
# 妆连庶儿首拍肩，晓歌欢马罗南层。他年沧桑知怀闲，层骨一分不来新。
# loss:0.732
# 等龙阴轩走变外，乘香破茫见防家。遥海子色五何发，黄微浮为钓冯唐。
# loss:0.702
# 设和波割闻红羊，行山三明汗人溪。海乘海波初田急，相似影腾雨来音。
# loss:0.720
# 县连番儿每拍肩，踏到一别年天风。初水东人何时夏，万拳情日逢大来。
# loss:0.672
# 工木仙乡似有林，叶年华语震来深。海日东山何余有，蚌是一湖安前狂。
# loss:0.706
# 艾蟹回当只自谋，金凭此味悦监州。双螯旧星炎抵尽，四绕异边争靖难。
# loss:0.700
# 辕蛇吞象不须齩，万岁化骨何阴狡。一非人年两儒白，天年应施贡烝兴。
# loss:0.759
# 琵悬腻新拄斗妍，醉载芳舵一鲲奔。遥散一日叶额碧，仗驰寒珠交牛蒙。
# loss:0.679
# 文好方传溯丁沙，送中成岸一日碧。海明风归扶海节。博归烟家一草金。
# loss:0.724
# 衡峰攒集黛螺青，玉岭如银沸胡山。有想万年图余老，台长张达一云仙长
# loss:0.746
# 填时伏英并可头，砌人妆叶惊画图。有人霜华有春得，耆堂烟味未方行。
# loss:0.718
# 垦蛇吞象不须齩，三岁化骨万阴狡。尔与尔雨鸟银国，酒学燃到赴翠花。
# loss:0.748
# 城重蚝国蜃气色，叶山红前拙残华。。懒生天人扶事，鲲望难兴作碧旻。
# loss:0.679
# 莫本由人性自春，功名富贵早超然。洛阳纵有耆英会，未及我公不老仙。
# loss:0.677
# 幛泉隐涧三尺波声丝到作西更持。日飞盛种成丈义，姿更浮幻海，轻出蔗
# loss:0.686
# 鼛字题沉北女婢，万地高瘴胜子天。到功意队波鱼得，踏花帆星争白明。
# loss:0.676
# 税裳春来天风空，，醅初叫不日花。南是晴槎金落役，一谷遥人不共渺。
# loss:0.696
# 俗箐飞神健卒娃，弄水守子照春深。他目但觉还万口，银龙真命女垒时。
# loss:0.703
# 釜泉残涧三尺嵩，到有登波不中节。雨界风人初毛渡，封将云水共一澄。
# loss:0.724
# 濯东自岸知，素屿文里利标柳。千知吹银来，挑漫清声佛人不难花。一山
# loss:0.648
# 蔽佛波露拖孙开，散云明阳一忉老。离乳握手知春护，春得归声无阴铃。
# loss:0.708
# 墨榜喧传姓氏先，四落从阁见连城。千甲岐似来时民，春来浮尽扶心明。
# loss:0.767
# 辇泉互玉荐西瓜，望腊先里图节妍。千年风天三，海，雄香风音霜首心。
# loss:0.658
# 诋门三景结经渡，仙里如诗焉道久。竹得蒲累有鬼治，故遣篱戈一烟花。
# loss:0.773
# 咫储狂骸欲竹到，偶摩烟步如天同。影阳秋愁得气在，官桐一树不知行。
# loss:0.746
# 崩泉下涧三尺波，女儿没水自群鹅。涛物神联未空贫，一隅蟾人细相未。
# loss:0.704
# 虚榜喧传姓氏先，文章从阁旧如旋。铁蛮有手是盈琴青生歌与处家。漫调
# loss:0.743
# 埋社丁徭力渐纾，番娘饷税早捐除。只今宵昼辛勤处，潮将官家十万储。
# loss:0.719
# 备得醉车政绩宣，甘棠载咏鱼诗荧。解标应兀惟兰手，管领清下解。好。
# loss:0.764
# 甲着单衫挥已教，散狂气香健舞东。海是同华调钧平，纵稀文语待头青。
# loss:0.719
# 妃峰攒集黛螺青，吹岭书彻旧看动。佛星佞风无时国，争钥西就争风月。
# loss:0.787
# 尤寂山山拖低路，年携衣射月更花。新今一年万却有，清背北徧消西曹。
# loss:0.734
# 环海修澜碧险斗，飕贲灰邑荖叶香。方女朱唇生酒晕，争看猱采耀烟谁。
# loss:0.678
# 开留学草水非山，濆沦轻濞咏盘使。疏张乞手赓鱼回，赖堂刊舶气瞬中。
# loss:0.725
# 沿寂波光拖玉练，更阑雌转荡珠盘。清池曾照禅心现，争开一桑远里新。
# loss:0.734
# 睹残海雨舞清春，瓮须妙拍蓬沙妍。楼余槟子红时春，有看鸿靖弓垂櫜。
# loss:0.699
# 髓工轻马秋人春，维漫拋光层云明。聚星亭落群峰难，钓耳已马不园芳。
# loss:0.770
# 陌裳山来新淼天，闲国由风是小鲜。疏桑金影歌翼渡，鹿鞭城影添朦胧。
# loss:0.762
# 难海繁翠能碧隐，每望空里夜风香。四年老幅回首近，鲸发咫花在四老。
# loss:0.792
# 翠沟交沸堪荒馔，下首无地尽火牛。十生在圃醉空来，旗花未家人此云。
# loss:0.738
# 鲁悬时排一新妇，下爱又与凤前湖。金腾竹甘身如中，旗常沉玉介寿眉。
# loss:0.759
# 也避声光日不西，大花回气一花风。碧声鬼牛远无翱，旗漫勋业符星头。
# loss:0.752
# 飕蝶浓象入紫城，南下南丝子天。。回载先路安伏东，太英金比耸珠公。
# loss:0.719
# 发有形骸杯可渡，万然出花使大溟。天轩坐镇喷雨市，浮里杳自尽生行。
# loss:0.777
# 挠蛇吞象见里点，治到南情闻如工。他别独头非同意，小画神虱春天。情
# loss:1.013
# 缪茶牛法世音温，入稻成堆雪荜鸡雷乘年深来白若有，欲年深处学画师。
# loss:1.129
# 播岚别味嚼里恙，谁槎岂长两清见。。雨露成瘴曾首里，山闻真边水春。
# loss:1.061
# 涉嫌水族名新妇，图爱一唱号兰平。芒带更渡暮寒敌，阡者衣忝尽号客。
# loss:1.136
# 玳泉蒙玉荐三险，云非波里隐碧车。换家汪鸡残生楣，笑者自声成气囷。
# loss:1.087
# 惟得散镖我盈会，入然利怪散天林。四时气去桅海妻，四出雌龙击滕曹。
